# %% [markdown]
# ## Logistic Regression model to predict if rating will be >= 4

# %%
# Import dependencies
import pandas as pd
import numpy as np

import pymssql

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Connect to the pymssql database server
con = pymssql.connect(server='rubinasqlserver.database.windows.net',
                      user='group4admin',
                      password='group4@pwd',
                      database='rubinasql',
                      timeout=0,
                      login_timeout=60,
                      charset='UTF-8',
                      as_dict=True,
                      appname=None,
                      port='1433')

cursor = con.cursor()

query = "SELECT * FROM dbo.SF_Data_geojson_full"

cursor.execute(query)

data = cursor.fetchall()

for item in data:
    print(item)
    
con.close()
# Out:
# {'Name': 'Marufuku Ramen', 'Review_count': 4122, 'Category': 'Ramen', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.785118103027344, 'Longitude': -122.4320068359375, 'Review': '[\'Long long overdue review, but I loved this place. The line was literally booty, so me and my friends went half an hour before opening, and sat by a nearby...\', "The food was amazing! I got the marufuku bites and the hakata tonkatsu, they were so good! The broth was the best I\'ve ever had, highly recommend!", \'Located inside a shopping mall, this is a perfect lunch spot. Come early and put your name down on the list and walk around the mall area to get some...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Japantown'}
# {'Name': 'Fog Harbor Fish House', 'Review_count': 8324, 'Category': 'Seafood', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.80898666381836, 'Longitude': -122.41029357910156, 'Review': '[\'Great food and not a long wait.  Perfect on a cool early afternoon.  Nice wait staff and right on the water.\', "Food was delicious! My wife and I were celebrating our wedding anniversary. Although the weather wasn\'t pleasant, we were able to see the Golden Gate Bridge...", \'Not bad, but not impressive at the same time.\\nThe service was pretty good, although they were busy.\']', 'Rating_binary': 4.5, 'Neighborhood': 'Fishermans Wharf'}
# {'Name': 'Dumpling House', 'Review_count': 360, 'Category': 'Dim Sum', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.763553619384766, 'Longitude': -122.4327621459961, 'Review': '["Love coming here - I\'ve gotten so many of their items and have been happy with each. I\'ve had their dumplings, the soups, vegetable dishes, you name it....", \'Back again for dinner tonight:\\n\\nOn point: \\n- XLBs\\n- Wonton with chili sauce\\n\\nLess so: Pork and cabbage dumplings\', "Not the best dim sum I\'ve had in SF... the restaurant itself is clean and modern, but the service was very very slow and the dim sum is quite Americanized...."]', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Starbelly', 'Review_count': 2115, 'Category': 'Comfort Food', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76401901245117, 'Longitude': -122.43253326416016, 'Review': "['Starbelly has been one of my go to comfort restaurants since I moved to this city. The menu is always fresh and new but the atmosphere and service always...', 'Came here for SF Restaurant Week 2022! The lunch comes with a starter and an entree for $15! What a DEAL. \\n\\nI ordered the 1/2 liver pate plate and chicken...', 'We came here for my coworkers bday, and it was great vibes all around.\\n\\nWe ordered a lot, and we spent $89/person for about 13 people. We ordered hella...']", 'Rating_binary': 4.0, 'Neighborhood': 'Castro'}
# {'Name': 'Bottega', 'Review_count': 379, 'Category': 'Italian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.75471878051758, 'Longitude': -122.42120361328125, 'Review': '[\'What a great place to grab lunch/dinner with your friends!\\n\\nThe servers are friendly. It adds that extra pizazz when they come by to offer freshly grated...\', "Ok let\'s debunk the hype - is Bottega really worth it? I say YES. \\n\\n| v i b e |\\nThe ambience is something I noticed right away. It feels airy with the big...", "I am dairy and gluten free... so why would I be posting a 5 star review? Well, it\'s because Bottega has gluten free pasta. Usually, gluten free pasta will..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Mission'}
# {'Name': "Jamie's Place", 'Review_count': 242, 'Category': 'Asian Fusion', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76261520385742, 'Longitude': -122.46598052978516, 'Review': '[\'Very good food and service is very friendly.highly recommend\\nWe order California omelet and it cooked perfectly. Dim sum is excellent\', "My friend introduced me to Jamie\'s Place and it\'s delicious. I love their presentation of food, and of course the food itself is very tasty. I think the...", \'Attempted to try this place multiple times, the first time I went got there before the store opened and waited and waited and waited, no sign of it being...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Beit Rima', 'Review_count': 200, 'Category': 'Arabic', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76595687866211, 'Longitude': -122.44967651367188, 'Review': "['Quick update:\\n\\nThese were great as well\\n\\nShashuka w cheese\\nWhole fried branzino-fish\\nFried potato', 'WOW! This restaurant truly is a hidden gem in Cole Valley. My boyfriend and I stopped in on a Sunday, not planning to go out for dinner. While driving by he...', 'The food is really good. We picked up, and they forgot something important, so we had to drive back, and they had accidentally given our item to someone...']", 'Rating_binary': 4.5, 'Neighborhood': 'Cole Valley'}
# {'Name': 'Sotto Mare', 'Review_count': 4621, 'Category': 'Seafood', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.79978942871094, 'Longitude': -122.40834045410156, 'Review': "['The food was delicious here! There was about a 45 min wait for two when we came in a Friday night, and they gave us a pager that would let us know when our...', 'Excellent !\\nThe best Italian food I ever had... Yum ! I mean it I never had Italian food that good pasta was done perfect sauce marinara is the best ever...', 'Absolutely the best place to meet friends to have the best Italian seafood in San Francisco. Sotto Mare serves old-school Italian seafood in an old-school...']", 'Rating_binary': 4.5, 'Neighborhood': 'North Beach'}
# {'Name': 'Dumpling Kitchen', 'Review_count': 27, 'Category': 'Dim Sum', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.7601318359375, 'Longitude': -122.43528747558594, 'Review': '[\'So totally thrilled to find this place! We just attended the grand opening today (10/8/22): the food was freshly delicious & the service seamlessly...\', \'A small storefront tucked in the heart of the Castro surprises you instantly if you walk in and ask to be seated in the back patio. We went midday on a...\', "FINALLY!!!!! This space and this neighborhood have a good restaurant!\\nOur first time so we played it safe and went our GOSB\'s (good old stand bys), bbq pork..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Kin Khao', 'Review_count': 2148, 'Category': 'Thai', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.785240173339844, 'Longitude': -122.40933227539062, 'Review': '["I\'ll start with saying the only reason it\'s not 5 stars is because  we ordered everything at once and asked to have it coursed some, and ended up with...", "It has been a long and rough few years, but luckily for us, it\'s finally over. No, not the pandemic, I\'m talking about waiting for Michelin-starred Kin Khao...", "This place has really really good food. Way over priced but they say that it is family sized portions... it\'s not. Portions are normal sized... so in other..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Downtown / Union Square'}
# {'Name': 'Surisan', 'Review_count': 2877, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.80678176879883, 'Longitude': -122.41755676269531, 'Review': "['Everything was amazing! The servers were welcoming and kind!!! I highly recommend this place', 'Whole ambiance and food was a vibe. Great and easy service and I like how the food was presented on the plates along with the fact that they taste...', 'Bro, this is a nice spot. The fried chicken is fire  I will definitely drive back to the city for this! I was super disappointed in the loco moco. I wanted...']", 'Rating_binary': 4.5, 'Neighborhood': 'Fishermans Wharf'}
# {'Name': 'The Snug', 'Review_count': 335, 'Category': 'Cocktail Bars', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.79093933105469, 'Longitude': -122.43443298339844, 'Review': '[\'Cool place, nice atmosphere! I love coming here with friends. If there are free places outside, I eat there. I usually take salads or french fries. Good...\', "We called ahead of time to double check if they allow dogs and they did (because they have parklets and that\'s where we stayed). Never got to see the inside...", \'Came on a Wednesday evening. Decently busy. No reservation and still sat us at a shared table. The menu is via a barcode you scan and order your food...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Pacific Heights'}
# {'Name': 'Farmhouse Kitchen Thai Cuisine', 'Review_count': 3388, 'Category': 'Thai', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76019287109375, 'Longitude': -122.41141510009766, 'Review': "['Food was good, good portiond, service was good as well.\\nHowever, way too expensive.\\nHow can this be rated 2x$ signs on Yelp? I have no idea', 'The food is excellent. The service needs improvement. Servers were rushing us through appetizers, drinks, dinner, and dessert. For an upscale restaurant,...', 'Atmosphere: 5/5\\nFood: 4.5/5\\nDrinks: 5/5\\nService: 5/5\\n\\nI had such a great time here catching up with a friend. The whole place is decked out in flowers so...']", 'Rating_binary': 4.0, 'Neighborhood': 'Mission'}
# {'Name': 'Purple Rice', 'Review_count': 218, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.771915435791016, 'Longitude': -122.43075561523438, 'Review': '["I\'ve been here twice now ever since moving to SF. I haven\'t had much good Korean restaurants in SF, but this place definitely fulfills my Korean food...", \'Decent Korean food for a fair price and a good quick spot in Hayes Valley! We came here on a Friday night a bit close to close - would recommend coming...\', \'As a gal who loves korean food, dare I say it is in my monthly rotation of eating out at least twice a month (which is generous considering the plethora of...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Lower Haight'}
# {'Name': 'Limoncello', 'Review_count': 1487, 'Category': 'Sandwiches', 'Rating': 5.0, 'Price': '$$', 'Latitude': 37.78731918334961, 'Longitude': -122.42359161376953, 'Review': "['Nice deli with Italian groceries, wine, and beer for sale. There are outside and limited indoor seating. \\n\\nI got The Godfather sandwich and it was OK the...', 'Aesthetic Italian store, huge sandwiches, slow service \\n\\nI called ahead to order my sandwich bc I had read reviews on how slow the service can be, and I...', 'I was visiting my daughter & son-law and we  stopped by Limoncello on our way to a park in San Francisco to pick up some Italian sandwiches. We had a little...']", 'Rating_binary': 5.0, 'Neighborhood': 'Cathedral Hill'}
# {'Name': 'Dumpling Home', 'Review_count': 673, 'Category': 'Dim Sum', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.77582931518555, 'Longitude': -122.42263793945312, 'Review': '["Im no noodle expert, but those ginger and green onion noodles were the best tasting, and definitely the best noodle texture I\'ve had. I almost ordered...", "I\'ve been wanting to try this place for a while but never had an excuse to go down to Hayes Valley. Normally I try to avoid that area because the parking...", "So many stellar reviews here.  I\'m going to be honest.  While the dumplings were nice and juicy, this place is overpriced.  The noodles at $16 is for one..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Civic Center'}
# {'Name': 'San Tung', 'Review_count': 7679, 'Category': 'Chinese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.7637825012207, 'Longitude': -122.46900939941406, 'Review': '["It\'s seriously over hyped. \\n\\nTo me chicken wings in a sticky sauce are nothing special. Chicken wings are not my idea of fine dining.\\n\\nThe black bean sauce...", \'Best food ever!!!\\r\\r Recently try the famous San Tung! ;)\\nPlace with the best fried chicken.\', "The wings here are amazing! Hands down the best wings we\'ve ever had!! On the other hand the costumer service I received here was horrible, that makes me..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Kitchen Story', 'Review_count': 3838, 'Category': 'Breakfast & Brunch', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76428985595703, 'Longitude': -122.43072509765625, 'Review': '["Good food, long wait & always busy. Kinda overhyped but it\'s a good benchmark for good brunch", \'We stopped in SF for our anniversary and stopped at this restaurant since we are bacon fanatics!\\nI really wanted to try out their bacon platter. \\nThis place...\', \'Classic brunch spot in SF with great bites. Kitchen Story has classic American brunch favorites with Asian influences.\\n\\nMenu includes omelets/scrambles,...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Mission Dolores'}
# {'Name': 'Wooden Spoon', 'Review_count': 540, 'Category': 'Breakfast & Brunch', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76661682128906, 'Longitude': -122.43025970458984, 'Review': '[\'Great food, great service & the ambiance is very nice. Shout out to Cubano and James! \\nThey were friendly and attentive. \\nIf visiting be sure to catch...\', \'Okay I had to come back here again because I was craving that soft scramble again! Once again my experience was the same just like before! This time I got a...\', "Decent brunch spot fix if there isn\'t a line. Servers were quite accommodating and friendly. Expect to wait about 30 min+ if you have a group larger than 2..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Duboce Triangle'}
# {'Name': 'Fable', 'Review_count': 736, 'Category': 'American (New)', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.75995635986328, 'Longitude': -122.43508911132812, 'Review': "['Came here for a late lunch. We were greeted by the host and had a reservation.\\n\\nWe sat out back and the back is so cute and refreshing. Service was great...', 'I would honestly rate this 3.5, but Yelp is forcing me to round..\\n\\nCame for a friends birthday dinner, and let me tell you, their outdoor patio is gorgeous...', 'Walked up to the place and noticed the small patch of seating in the front. Nice peaceful greenery in the crazy city. As we went inside we waited a little...']", 'Rating_binary': 4.0, 'Neighborhood': 'Castro'}
# {'Name': 'Woodhouse Fish Company', 'Review_count': 2475, 'Category': 'Seafood', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.787418365478516, 'Longitude': -122.43327331542969, 'Review': '["TL;DR - small and cute spot, great for date night and they have oyster Tuesday\'s \\n\\nThis place is adorable. I love the counter seats too. It\'s a small place...", \'Super cute restaurant in the heart of the trendy Fillmore District in lower Pac Heights. \\n\\nWe sat in their outdoor open parklet for lunch on a sunny Tuesday...\', \'Words cannot express how delicious and good it is.  Just give a shot! Then you will understand what I mean. \\nChunk lobster chilled in Mayo and celery.....\']', 'Rating_binary': 4.0, 'Neighborhood': 'Japantown'}
# {'Name': 'JIJIME', 'Review_count': 496, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78065490722656, 'Longitude': -122.47895050048828, 'Review': '[\'Came here for a late lunch. I was greeted and seated immediately. I got the tonkatsu ramen. It came out fairly quickly and piping hot.\\nIt was very filling...\', "Interesting food concept Korean Asian fusion and they advertise as such & I\'m not sure what that is exactly. Scanning the menu, it\'s predominately Korean...", \'The boyfriend and I had dinner here before we went to our show at the Palace theater. it was only 12 min away, so location was good for us, and when I saw...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'Parada 22', 'Review_count': 1385, 'Category': 'Latin American', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76921844482422, 'Longitude': -122.45211791992188, 'Review': '[\'The waiter was super accommodating and thoughtful. We got there with our pup and the waiter made sure our pup has water too. He moved us to one of the patio...\', "I don\'t know if I\'ve ever had Puerto Rican cuisine prior to Parada 22, but I\'m so happy I live pretty close to here, so I can try more of their dishes more...", \'Vegetarian plate was generally okay - the white beans and yucca were more saucy than I expected but ratio of rice was not quite there. Some nice flavors for...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Haight Ashbury'}
# {'Name': 'Tanglad', 'Review_count': 209, 'Category': 'Vietnamese', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76149368286133, 'Longitude': -122.43484497070312, 'Review': '["This place is way nicer than the pictures  online make it seem! It\'s actually a super cute vibe and has a pretty outdoor area. \\n\\nThe food was amazing as...", \'Stopped in near closing and they were kind enough to serve me a combo pho right quick.  I had heard mixed reviews of some of their other menu items, but...\', "This was a pleasant surprise hidden out in the Castro. My husband and I stopped in on a whim, and we\'re very glad we did.\\n\\nThe restaurant had a semi-outdoor..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Hook Fish', 'Review_count': 858, 'Category': 'Seafood', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76237106323242, 'Longitude': -122.50685119628906, 'Review': '[\'I am obsessed with this place. I was intimidated at first and started with avocado tacos, then moved on to their poke salad. Once I had a taste of their...\', "LOVE this place - was surprised by how good it is! Right by Ocean Beach, it\'s the perfect spot to grab a bite after exploring the area.\\n\\n* Fish + chips:...", "Holy smokes this place is good. It\'s a small space that only has limited outdoor seating, but has a cool open kitchen and a menu focused on, you guessed it,..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Outer Sunset'}
# {'Name': 'Breadbelly', 'Review_count': 410, 'Category': 'Bakeries', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78274917602539, 'Longitude': -122.4743881225586, 'Review': '[\'Breakfast Sandwich: Bursting with flavors and unexpected ingredients. A unique twist on an American classic, the breakfast sandwich. Featuring pickled...\', \'The concept is lovely the execution of pastries are top notch.  However, I felt their star "Pandan Toast" was too sweet for me and for $10 seemed a little...\', \'*3.5 stars, Came here on a sunny Saturday morning for brunch and line was ~15min long. No inside seating & bathroom available but there were plenty of...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Pizzetta 211', 'Review_count': 1413, 'Category': 'Pizza', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78368377685547, 'Longitude': -122.48297119140625, 'Review': "['Easily my favorite spot in SF. Came by for Pearl (also amazing), and was convinced to come back for Pizzetta. As a New Yorker, I was skeptical of California...', '*calls to order a spicy coppa pizza* .... Have you seen our updated menu from our website? We change it every two weeks *doohhhh sorry I shall call back*...', 'Out in the quiet residential neighborhood a warm glow falls on the beautiful sidewalk in front of this rustic cozy teeny restaurant.  A pizza oasis,  like a...']", 'Rating_binary': 4.5, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'Nopa', 'Review_count': 5300, 'Category': 'American (New)', 'Rating': 4.0, 'Price': '$$$', 'Latitude': 37.77482986450195, 'Longitude': -122.43746185302734, 'Review': "['The service was great, the food was wonderful.  I took my family here and had been anticipating the pork chops.  It did not disappoint us at all!  You gotta...', 'Nopa is a restaurant that focuses on combining quality, seasonal ingredients without over amplifying their menu. I got their smoked tomato Caesar salad,...', 'This place did not live up to its hype at it. We walked in for date night on Friday around 7:30pm with no reservations, and luckily we got seated instantly...']", 'Rating_binary': 4.0, 'Neighborhood': 'Alamo Square'}
# {'Name': 'Horsefeather', 'Review_count': 459, 'Category': 'Cocktail Bars', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.77450180053711, 'Longitude': -122.4373550415039, 'Review': '["Gorgeous restaurant and bar where you feel like you\'re in a greenhouse if you\'re sitting in the patio area - so fun and intimidate \\n\\nMy favorite was the...", \'We came here on a weekend night with no reservation and were able to get seated at an outdoor table pretty quickly! I loved the vibe of the place - very...\', \'Stopped by here for my birthday and loved the aesthetics, the plant walls were adorable and love that they have an outside part, semi outside part, and...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Alamo Square'}
# {'Name': 'Sweet Maple', 'Review_count': 4429, 'Category': 'American (Traditional)', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.785736083984375, 'Longitude': -122.4350814819336, 'Review': "['Wonderful establishment......fantastic food and terrific staff.....thank you SM............', 'My wife was looking for a great place for brunch and Sweet Maple had some great reviews on Yelp. \\n\\nThe Yelpers were spot on!\\n\\nWe were a little worried about...', 'Came here on a Saturday for a solo brunch and lovedddd it! \\n\\nThere was a pretty long line wrapping around the corner but since I was alone I got to skip the...']", 'Rating_binary': 4.5, 'Neighborhood': 'Lower Pacific Heights'}
# {'Name': 'Dumpling Kitchen', 'Review_count': 1952, 'Category': 'Chinese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.7422981262207, 'Longitude': -122.48700714111328, 'Review': '[\'Stopped by here on a Saturday afternoon for a late lunch around 3pm. We were immediately seated and handed menus. \\n\\nWe ordered the following items: \\n-...\', \'Stopped by here for lunch this past Thursday on the recommendation of my girlfriend. I have to say I was thoroughly impressed.\\n\\nMy girlfriend and I split a...\', "Oh my Dumping Kitchen.  You know I love me some dumpin\'s!\\n\\nWe got some Egg Yolk stuff!  Some Steamed Bun stuff!  And some Shanghai stuff!\\n\\nI dunno.  I..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Parkside'}
# {'Name': 'The Italian Homemade Company', 'Review_count': 1122, 'Category': 'Italian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.797420501708984, 'Longitude': -122.43096923828125, 'Review': "['It was my first time in San Francisco I order the lasagna it was amazing  it was a big plate  for like 2 people .. I will definitely go back when I  go...', 'The panna cotta was the one who stole the show for me! It was so creamy, the berry sauce was the right amount of sweetness. I would honestly say it is...', 'Will add my review to the pile for this one - cute little spot with nice but lowkey seating - could be a casual date night, or a lovely dinner with a small...']", 'Rating_binary': 4.5, 'Neighborhood': 'Union Street'}
# {'Name': 'Santeria', 'Review_count': 227, 'Category': 'Mexican', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.764835357666016, 'Longitude': -122.43180847167969, 'Review': '["Delicious, excellent service, great drinks and food! I ordered flautas and a margarita and was the best decision of my life! I\'ll totally visit again", \'Highly recommend Santeria. Visited this neighborhood gem on a slightly busy Tuesday evening. No reservation and still sat us at nice table. The owner, Lalo...\', \'Fresh off the plane having just landed at SFO, we were hungry and ready to eat. Thanks to Yelp, I had found Santeria beforehand and knew that we would be ok...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Udon Mugizo', 'Review_count': 1251, 'Category': 'Japanese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.785011291503906, 'Longitude': -122.4317398071289, 'Review': "['I always come here and almost always get the mentai cream udon. I definitely think this is a great spot for a casual dinner with a friend, as other reviews...', 'I think this place is okay if you want a quick lunch/dinner, nothing crazy.\\n\\nI got the deluxe udon with tempura, pork belly, and tender beef. The beef did...', 'Less toppings then more expensive then last visit. It was not even 1 year ago. \\nmore expensive then less food in bowl is unacceptable!! \\nNow charge for tea....']", 'Rating_binary': 4.0, 'Neighborhood': 'Japantown'}
# {'Name': 'Souvla', 'Review_count': 541, 'Category': 'Mediterranean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.774478912353516, 'Longitude': -122.43801879882812, 'Review': '["Excellent. I\'m absolutely coming back. I was genuinely impressed at how good everything was. \\n\\nNot only was the food ready pretty quickly, it tasted...", "I\'m done ordering from this Souvla. The last 3 times they\'ve messed something up:\\n\\nJul 6, 2022 | Order # c082cfdd: Actually gave us completely the wrong...", "An SF Staple! I love bringing my friends who visit the city here, as a quick bite that\'s a little elevated. Of course, it\'s pricier than typical fast food,..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Panhandle'}
# {'Name': 'Pearl 6101', 'Review_count': 386, 'Category': 'Italian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78383255004883, 'Longitude': -122.48304748535156, 'Review': '["The cutest little restaurant for a cozy hangout or date night! While there is indoor and outdoor seating, I\'d recommend getting a reservation beforehand...", \'Came here for dinner on a Sunday and it was still pretty packed! \\nOur server was super sweet and recommended a couple of their favorites. \\nWe ended up...\', \'Want an incredible place just a few blocks away. \\nCame to Pearl for a celebratory dinner and this place was perfect. The service was excellent and we were...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'Daeho Kalbijjim & Beef Soup', 'Review_count': 1485, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$$', 'Latitude': 37.7860107421875, 'Longitude': -122.42858123779297, 'Review': '[\'Fast phase service and ofcourse Good!Good!Good! food!went there for the weekend and they have a long waitlist, but i can say it is WORTH THE WAIT!\', "100% love their combination beef soup and cheese Kalbijjim! Very flavorful beef ribs and cream soup, great to have it to warm up in the cold winter! \\n\\n(It\'s...", \'Decided to come here for dinner with a few friends on a Friday night. We put ourselves on the wait list prior to arriving and our tables were ready by the...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Japantown'}
# {'Name': 'Lokma', 'Review_count': 538, 'Category': 'Mediterranean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78215026855469, 'Longitude': -122.47866821289062, 'Review': "['The server was the sweetest. So attentive and always checked on us throughout our meal. I had such a positive experience at Lokma. \\n\\nThe ambiance of the...', 'Variety of vegetarian options: 5/5\\n\\nLove lokma! Fresh squeezed orange juice is awesome and the bal and kaymak is a huge hit and tasted really authentic....', 'We tried Lokma while staying in a nearby AirBnB and really enjoyed it.\\n\\nWe enjoyed 2 entrees, dessert, (Baklava) wine and beer. I especially recommend the...']", 'Rating_binary': 4.5, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'California Fish Market Restaurant', 'Review_count': 477, 'Category': 'Seafood', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.799800872802734, 'Longitude': -122.40831756591797, 'Review': '[\'Came here on a week night for a birthday dinner and was not disappointed. There was live music at a near by restaurant so opted to sit outside and were...\', "I\'ve been looking forward to this restaurant since they opened. Service is speedy and friendly. \\n\\nWe ordered the salmon and scallop crudo. Fish market...", \'Not quite sure what I expected, maybe I was thinking it would be more wooden interior and old school vibe, but what we got was better! The main server, just...\']', 'Rating_binary': 4.5, 'Neighborhood': 'North Beach'}
# {'Name': 'Mamahuhu', 'Review_count': 279, 'Category': 'Chinese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78266906738281, 'Longitude': -122.46492767333984, 'Review': '[\'First time trying this spot and blown away! We got the sweet and spicy chicken sandwich and it was bomb! The sauce was so delicious-it left a spicy taste in...\', "I think Mamahuhu is a solid fast casual spot in the Richmond. The interior is super cute and colorful. They have a nice patio area that\'s great on a sunny...", \'Best way to describe the food? Everything was very good, but nothing was memorable. Simply put: Quick, healthy, and fresh. Nothing more. Nothing less....\']', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Nopalito', 'Review_count': 1992, 'Category': 'Mexican', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.773433685302734, 'Longitude': -122.43899536132812, 'Review': '["This is going on my public list of the Bay Area\'s Best Mexican Cantinas. This restaurant has it all, great food, amazing vibe, parking easy to find, superb...", \'Always had a delightful breakfast there. I am very interested in trying the breakfast that is served here. So many great options and the quality of food is...\', \'The food is delicious as always, but the new ToastTab system takes away from the charm and fun of eating out. With their new system, you order food online...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Panhandle'}
# {'Name': "MaMa Ji's", 'Review_count': 856, 'Category': 'Dim Sum', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76075744628906, 'Longitude': -122.43872833251953, 'Review': '[\'What can I say? This place was amazing!! Amazing food, good price, and I love outdoor seating on a beautiful day. \\n\\nI never heard of this place, but the...\', "This spot is a small neighborhood Chinese restaurant that makes a particular Sichuan dish that I love very very well: the Hot and Numbing Fish. \\n\\nI\'ve...", \'Another friggin grand slam ... I had been in a hospital just shy of a week...... and the first thing I wanted and craved was dumplings and noods from this...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Eureka Valley'}
# {'Name': 'Burma Superstar', 'Review_count': 7276, 'Category': 'Burmese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78278732299805, 'Longitude': -122.46253967285156, 'Review': '[\'I really liked the check in tablet at the Host reception. It was a 27 minute wait, so we were able to go to a nearby Bar to kill time. We got the alert and...\', "I\'ve been to burma before and the quality is always consistent! We went at 6 on a Tuesday and there wasn\'t a wait despite being busy. We ordered the mango...", \'Tried this restaurant today. Food tasted not bad but there is always a line there.\\n\\nPrice was not super expensive but somewhat high.\']', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Perilla', 'Review_count': 1477, 'Category': 'Vietnamese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.7641487121582, 'Longitude': -122.46710968017578, 'Review': '[\'#27 imperial rolls & 5-spice chicken garlic noodle is *fantastic*! Noodles are garlicky and perfectly al dente. Egg rolls are SO crispy and tasty...\', "This was the Vietnamese place I had heard most about after moving to SF. I\'m never in Inner Sunset so was excited to head over on for a Saturday dinner!...", \'Love this place. Their portions are giant yet delicious. We ordered the five spice chicken with garlic noodles and imperial rolls. And the grilled pork with...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Cha Cha Cha', 'Review_count': 3376, 'Category': 'Caribbean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.769142150878906, 'Longitude': -122.45204162597656, 'Review': "['Laura was so attentive and patient with our large group of 13! She continuously checked up on us and was so quick to respond to any question or concern we...', 'Out to lunch with the pre-teens today enjoying an unexpected school holiday.  We were vintage clothes shopping on The Haight and had to come to eat here.  I...', 'Great lunch spot for Cuban food. We had the flavorful Ropa Vieja and the roasted pork. Both had a ton of flavor. \\n\\nService was good and prices ok for San...']", 'Rating_binary': 4.0, 'Neighborhood': 'Haight Ashbury'}
# {'Name': 'Jane on Fillmore', 'Review_count': 1111, 'Category': 'Coffee & Tea', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78934097290039, 'Longitude': -122.4342269897461, 'Review': '[\'Not bad! I found some tasty food... I like their berry smoothie bowls. Also, I recently had peanut butter and banana toast. \\nThe place is not big, if I can...\', "Love Jane\'s. Great coffee,pastries and atmosphere. Such a treat to get a table up front and watch the people pass by on Filmore.", \'I enjoyed a casual breakfast at Jane on Fillmore earlier this week! I was so tempted by several of the menu items, and would definitely return to try them...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Pacific Heights'}
# {'Name': "Brenda's Meat & Three", 'Review_count': 1377, 'Category': 'Breakfast & Brunch', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.77814865112305, 'Longitude': -122.43855285644531, 'Review': '["Delicious brunch spot, doesn\'t lose in anything to the Polk St unit. This one takes reservations in advance! My favourites were: The shrimp and grits,...", \'Such good vibes here. I came as a party of 6 on a Sunday noon and we were seated in about 20 minutes. \\n\\n- chicken sandwich (5/5)\\n- French toast (3/5)\\n-...\', \'10/16/22 Sunday 3 pm \\nWe came looking for soul food in the area open past 3 pm. (Many restaurants are closed at 2 pm). Simple menu with attractive enough...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Western Addition'}
# {'Name': 'Cafe Okawari', 'Review_count': 245, 'Category': 'Japanese', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.77825927734375, 'Longitude': -122.39388275146484, 'Review': '["Chicken katsu sando. That\'s the only thing you need to know. \\n\\nBetween all the meetings, my coworkers and I were struggling to coordinate a time where we...", \'The chicken katsu curry is delicious, and I think what sets it apart is that the chicken has clearly been marinated. When you bite in you get a savory...\', \'\\\\\\\\ TO GO ORDER REVIEW //\\n\\nI ordered:\\n- chicken katsu sando with curry sauce on the side\\n- spicy tuna don\\n\\nThe chicken katsu sando was so decadent. The milk...\']', 'Rating_binary': 4.5, 'Neighborhood': 'South of Market'}
# {'Name': 'Saucy Asian', 'Review_count': 407, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.762611389160156, 'Longitude': -122.43093872070312, 'Review': '["I stopped in for Poke after the gym. I ordered the island poke with a mix of tuna and salmon. This was some of the most flavorful Poke I\'ve ever had! I...", "Saucy Asian is the perfect, quick (and sneakily maybe nap inducing) lunch to pick up in the Castro / Dolores area. I\'ve never been when there has been a...", \'Have been here dozens of times and loved it.\\n\\nHowever, the last handful of times, the amount of food they gave has declined rapidly.  They are skimping on...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Cafe De Casa', 'Review_count': 126, 'Category': 'Brazilian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.762359619140625, 'Longitude': -122.43470764160156, 'Review': '["I think i\'ve found my açaí spot! I\'ve been on the hunt for a while, having tried earthbar, avotoasty, judahlicious etc, and I\'ve not found a click. It\'s...", \'Large, delicious, and refreshing smoothie bowls for a good price! I love toppings so appreciated all the granola and fruit, but if you prefer more smoothie...\', \'Cafe De Casa has routinely become one of my favorite spots to work on a Friday afternoon. Their pastries are to DIE for especially their cheese bread (pão...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Zazie', 'Review_count': 4932, 'Category': 'Breakfast & Brunch', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76524353027344, 'Longitude': -122.4500961303711, 'Review': '["The food was great - I\'m  just not sure it was worth the wait in the end.\\n\\nThe waiting system was transparent and efficient though! It was entirely our...", \'I think I had really high expectations before going so it fell a little flat for me. The food was okay and ambiance was nice but I left feeling a bit...\', \'Fantastic spot for brunch in SF, highly recommend the cappuccino!  Heads up there is always a wait so make sure to get on the list earlier than later.\']', 'Rating_binary': 4.0, 'Neighborhood': 'Cole Valley'}
# {'Name': 'Um Ma', 'Review_count': 576, 'Category': 'Korean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.765499114990234, 'Longitude': -122.46619415283203, 'Review': '["It\'s been a really hard to find a good Korean restaurant in SF; UMMA almost hit the spot!\\n\\nWe put our name on the waiting list for umma and waited for about...", "My last two visits here weren\'t as good as the previous three visits. Last time I thought it was because I decided to try a new dish rather than my usual...", "A pleasantly surprised experience! To be honest I was a little bit skeptical of the restaurant since it was supposedly Korean food but it didn\'t seem / feel..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Troya', 'Review_count': 684, 'Category': 'Mediterranean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78937530517578, 'Longitude': -122.43407440185547, 'Review': "['After 2 years I came back to la Troya with my husband, his parents and a friend of us.\\nI booked online, but my husband call to be sure the table was inside...', 'While in between work meetings, I grabbed a quick lunch at Troya on a Friday afternoon. It was...fine. \\n\\nI originally came because I saw the Manti Dumplings...', 'Troya is the real deal. Everything that we tried was exceptional. \\n\\nHowever, there are two dishes that stole the show. The braised lamb shoulder and the...']", 'Rating_binary': 4.0, 'Neighborhood': 'Pacific Heights'}
# {'Name': 'NOVY Restaurant', 'Review_count': 498, 'Category': 'Mediterranean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.751529693603516, 'Longitude': -122.43212127685547, 'Review': '[\'Highs:\\n- We liked everything we ordered: the chicken wrap (gyro), Athenian pasta, and moussaka. Each plate was filling enough for one person. \\n- We tried...\', \'We made an 8pm outdoor reservation online.  The food was great, the service was friendly, and the outdoor set up was quite pleasant.  The only downside is...\', "Best dolmas that I have ever had, and I\'ve had quite a few.  We came and had  sort of a small plates dinner with dolmas, halloumi cheese, hummus and one..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Noe Valley'}
# {'Name': 'Presidio Kebab', 'Review_count': 259, 'Category': 'Mediterranean', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.7880744934082, 'Longitude': -122.44680786132812, 'Review': '[\'Weary Travelers. As we were headed to a typical food chain restaurant to eat because we were too tired and too hungry to explore. We see this elegant...\', \'Ordered the hummus, babaganoush, falafel appetizer, spanakopita, L&B-yaprak wrap, musakka, salmon izgara, beyti kabob, baklava, and kunefe for takeout\\nThe...\', "I came here for late lunch on Sunday. \\n\\nI had Beyti Kebab and Kunefe. Beyti kebab one of the best I\'ve ever had. Homemade kunefe was fresh and delicious.\\nI..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Presidio Heights'}
# {'Name': 'Beretta', 'Review_count': 321, 'Category': 'Italian', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.77574920654297, 'Longitude': -122.43824768066406, 'Review': '["Food and drinks were some of the best I\'ve ever had. I had the lasagna... DELICIOUS. A table favorite.  I don\'t know if I\'ll be able to get lasagna anywhere...", \'The best valued happy hour in my opinion!\\n\\nExperience: My friend and I went here at 4pm. We were seated immediately. We sat outside and the outside seating...\', \'Walnut bread with burrata and mushroom-truffle honey. Get it. Burrata is always amazing, but it was even better paired with a soft and chewy walnut bread,...\']', 'Rating_binary': 4.0, 'Neighborhood': 'Panhandle'}
# {'Name': 'Manna', 'Review_count': 1280, 'Category': 'Korean', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76388931274414, 'Longitude': -122.46724700927734, 'Review': '[\'???????????????????????????????6??????????????????????\\n??????????????????????????????????????????????????????????????????????????????????????????????????????...\', "There aren\'t too many solid Korean restaurants in SF, so I\'m glad I found this one! Though small and tightly packed, this place was the pinnacle of...", "An Inner sunset classic...affordable Korean eats in SF with friendly service! Manna is always a good idea. I\'ve eaten here many times over the years and the..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Mangrove Kitchen', 'Review_count': 349, 'Category': 'Thai', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.77251052856445, 'Longitude': -122.43695831298828, 'Review': '[\'Great food. Amazing atmosphere and phenomenal service. Will absolutely be back again.\', \'Variety of vegetarian options on the menu: 4/5\\n\\nWent once and have been back almost 3 more times. Mangrove might be our new go to Thai spot! We also get the...\', "Mangrove is my local Thai restaurant for when I can\'t wait for delivery or I don\'t want to travel far for dinner. I\'m giving them 3 stars for convenience..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Lower Haight'}
# {'Name': 'Unco Frank’s', 'Review_count': 67, 'Category': 'Hawaiian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.7828483581543, 'Longitude': -122.46411895751953, 'Review': '[\'Fantastic spot for Hawaiian food in an unsuspecting location. We shared the kalbi, mochiko chicken, and furikake fries.\\n\\nKalbi: Good amount of meat and fat...\', "Food was great and great customer service.I had teriyaki chicken with two sides \\n\\nThe reason I\'m giving it 4 stars way to pricey $19 for the chicken and...", "First of all, placing an order for pickup is NOT EASY.  Unco Frank\'s does not have a direct web presence.  You need to place your order through:..."]', 'Rating_binary': 4.5, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Savor', 'Review_count': 51, 'Category': 'Mediterranean', 'Rating': 5.0, 'Price': '$$', 'Latitude': 37.76411437988281, 'Longitude': -122.46223449707031, 'Review': '["Wow, we\'ve had brunch here several times and the savory dishes are AMAZING! All the dishes we\'ve tried have been wonderfully seasoned and incredibly well...", \'Truly makes you want to savor every bite. Incredible combination of quality ingredients and delightful flavours.\\n\\nAppearing quite reserved at first glance,...\', "I\'ve followed Chef Mo for years - he\'s always had the best vegetarian food and at his new place here on Irving - it\'s just as I remembered maybe even..."]', 'Rating_binary': 5.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'San Ho Won', 'Review_count': 223, 'Category': 'Korean', 'Rating': 4.5, 'Price': '$$$$', 'Latitude': 37.75944137573242, 'Longitude': -122.41017150878906, 'Review': '[\'I was so excited to dine at San Ho Won, after having an amazing experience at Benu, several years ago.  It did not disappoint.   Our group had the house...\', "Best I\'ve ever had. Exceptional food down to every last detail. \\n\\nWill be back for sure.", \'The service here is amazing and the food was delicious and beautifully presented! My friend and I walked in around 5:30pm on a Wednesday and we were given...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Mission'}
# {'Name': 'Hinodeya Ramen Bar', 'Review_count': 1673, 'Category': 'Ramen', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.786155700683594, 'Longitude': -122.4300537109375, 'Review': "['The best ramen I ever had, I got the level 10 and they did a great job of balancing the flavor with spice. Props to the chefs! Nonetheless the spice left me...', 'My favorite vegan ramen in the city!!! The flavors are PACKED and all the toppings are soooo good! Squash? Yes. Inari??? Yes! And the staff is so attentive,...', 'Came here with a friend who was visiting from out of town. We had just gotten back from a giant sandcastle building competition on the beach so we wanted...']", 'Rating_binary': 4.0, 'Neighborhood': 'Japantown'}
# {'Name': 'The Italian Homemade Company', 'Review_count': 1794, 'Category': 'Italian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.80175018310547, 'Longitude': -122.41184997558594, 'Review': '["craving home made pasta?\\n\\nliterally is in the name of the restaurant\\n\\never since the italian homemade opened its first location in SF - i\'ve been a fan!...", \'Food is great. Tasty and good portions.\\n\\nI removed one star because the attention to detail no so great.  I ordered delivery from the North Beach location....\', "Saw so many great reviews, but I don\'t understand why.\\n\\nPrice review\\nFirst, the price was shocking! I think it would have been cheaper at Olive Garden where..."]', 'Rating_binary': 4.5, 'Neighborhood': 'North Beach'}
# {'Name': 'Hodala', 'Review_count': 651, 'Category': 'Taiwanese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.780006408691406, 'Longitude': -122.48168182373047, 'Review': "['i loveee the ground pork with rice bowl and the shaved ice :) but honestly everything ive had so far is great. if possible, i would like to see more milk...', 'Came here for some hot beef noodle soup at around 5:30pm on a cold, foggy Sunday evening. \\n\\nVery authentic Taiwanese spot with the Taiwanese gua baos and...', '5.5/10\\nDate of visit: September, 2021\\n\\nBasically everything was kinda meh other than the radish/turnip cakes, which were cubed and fried style but not...']", 'Rating_binary': 4.0, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'The Public Izakaya', 'Review_count': 95, 'Category': 'Izakaya', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.787837982177734, 'Longitude': -122.4135971069336, 'Review': "['I love going to this place with my girlfriend. I really like the delicious food and the relaxed atmosphere of the restaurant', 'Food and atmosphere were great, but Anthony was incredible! Very attentive and kind to us throughout the meal. Would genuinely go back again just for him,...', 'I love the ambiance!! Super cozy and really unique vibe! I would recommend this place to anyone!']", 'Rating_binary': 4.5, 'Neighborhood': 'Lower Nob Hill'}
# {'Name': 'Lavash', 'Review_count': 1527, 'Category': 'Persian/Iranian', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.764068603515625, 'Longitude': -122.46342468261719, 'Review': "['Highly recommend the goat tongue and Lavash special. And please try the rose water noodle dessert, so refreshing!', 'The food is ok! The owner has attitude! But the workers are very sweet! And the stars are just for them.', 'i was back in town and began to dream of Lavash.\\nEach dish mor stellar than the last. \\nmy advice -- try the Lentil soup and Feta, I adore the lamb shank,...']", 'Rating_binary': 4.0, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Delarosa', 'Review_count': 1804, 'Category': 'Italian', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.80028533935547, 'Longitude': -122.4391098022461, 'Review': '[\'Good quick eat pizza place in the Marina. \\n\\nWe stopped by while spending a day in SF. And wanted to try something new. \\n\\nWe were seated quickly as they had...\', \'We chose delarosa to start our date night. We went pretty early ~6 pm since our show starts at 8. The place was pretty packed, the boyfriend did call in the...\', "The margarita wasn\'t spicy, and there isn\'t enough space for people to sit comfortably. I would not advise eating here during peak hours. I visited on a..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Marina'}
# ...
# {'Name': 'Tommaso Ristorante Italiano', 'Review_count': 1746, 'Category': 'Italian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.79777908325195, 'Longitude': -122.40520477294922, 'Review': '["I am shocked I have never written a review for this yummy restaurant. Pizza, pizza, and lots of other great tasty food. This place is a gem. I\'ve been...", \'When we lived in San Francisco, we dined at Tomasso at least twice a month, so it was very comforting to return after an absence of several years and find...\', \'Went to this gem of a spot last night. We had been wanting to check this place out since we passed by it often and the parklet had a nice big sign of the...\']', 'Rating_binary': 4.5, 'Neighborhood': 'North Beach'}
# {'Name': 'Tacolicious', 'Review_count': 1728, 'Category': 'Cocktail Bars', 'Rating': 3.5, 'Price': '$$', 'Latitude': 37.800411224365234, 'Longitude': -122.44047546386719, 'Review': '["I went to Tacolicious a couple of times when they were at the original location on Chestnut Street near Fillmore. It\'s an above average place in the Marina...", \'After playing a round of tennis yesterday, my girlfriend and I stumbled upon this place in the Marina while walking along busy Chestnut street. \\n\\nWe were...\', "Every time I\'m in town, I try to stop by this location. I\'ve been going to Tacolicious for a very long time; back when they were at the other location on..."]', 'Rating_binary': 3.5, 'Neighborhood': 'Marina'}
# {'Name': 'Waterbar', 'Review_count': 3526, 'Category': 'Seafood', 'Rating': 3.5, 'Price': '$$$', 'Latitude': 37.79049301147461, 'Longitude': -122.3890380859375, 'Review': '[\'During my SF days, so much of my time was spent near or around Waterbar, that I am amazed that it took me this long to dine here. Perhaps, it was most of my...\', \'This was my first time at Waterbar and it was a 5/5 experience! We had a reservation for 3 on a beautiful (!) Saturday afternoon, and even seated indoors we...\', "Honestly from the start got attitude from either the business manager or whoever is in charge of managing the inside of the restaurant. I\'ve been here..."]', 'Rating_binary': 3.5, 'Neighborhood': 'Rincon Hill'}
# {'Name': 'Waterbar', 'Review_count': 3526, 'Category': 'Seafood', 'Rating': 3.5, 'Price': '$$$', 'Latitude': 37.79049301147461, 'Longitude': -122.3890380859375, 'Review': '[\'During my SF days, so much of my time was spent near or around Waterbar, that I am amazed that it took me this long to dine here. Perhaps, it was most of my...\', \'This was my first time at Waterbar and it was a 5/5 experience! We had a reservation for 3 on a beautiful (!) Saturday afternoon, and even seated indoors we...\', "Honestly from the start got attitude from either the business manager or whoever is in charge of managing the inside of the restaurant. I\'ve been here..."]', 'Rating_binary': 3.5, 'Neighborhood': 'Rincon Hill'}
# {'Name': 'Basa Seafood Express', 'Review_count': 917, 'Category': 'Seafood', 'Rating': 4.5, 'Price': '$', 'Latitude': 37.75276184082031, 'Longitude': -122.41338348388672, 'Review': '[\'I LOVE THIS PLACE cheap and great fish. They offer fishes in different sauces/marinades without any of the other stuff at poke bowl places. Combos are...\', "I didn\'t know a place like this exists in Sf! 10$ specialty rolls that aren\'t total garbage?!? I\'m in! \\n\\nNestled in the mission- basa- offers juicy and...", \'Basa Seafood Express is, no surprise, excellent quick seafood. We did an order pick up and you can skip the lines if you do this. The rolls are really...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Mission'}
# {'Name': 'Rossi’s Deli', 'Review_count': 186, 'Category': 'Delis', 'Rating': 4.5, 'Price': '$', 'Latitude': 37.76205062866211, 'Longitude': -122.43537902832031, 'Review': '[\'This is the biggest secret on Castro St. It is impossible to find a super amazing falafel in the whole city, but theirs is good. Their other sandwiches are...\', "I\'ve walked by this deli many times in the Castro. I probably went in once or twice. I decided to try the sandwiches today and I had the reuben to start....", \'WHEN: 11/27 Saturday @ 5pm\\n\\nMy family and I came to Castro and walked around since we were already in SF. The whole city is super busy and lively with...\']', 'Rating_binary': 4.5, 'Neighborhood': 'Castro'}
# {'Name': 'Mikawa', 'Review_count': 21, 'Category': 'Japanese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78181076049805, 'Longitude': -122.48552703857422, 'Review': "['Trying out another small local Japanese restaurant.\\n\\nQuality/Quantity -\\nTonkatsu Curry - Breaded deep fried pork cutlet. One of their specialities, well...', 'This place aaa delicious! My husband and I went there on a breezy Monday night after a long walk. He got the tonkasu ramen: delish noodles, good broth and...', 'Take out dinner.  Was not crowded.  \\n\\nI ordered the chicken teri bento box.  The box comes with 2 tempura shrimp and 3 pieces of veggie.  You can gave 2...']", 'Rating_binary': 4.0, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'Tartine Manufactory', 'Review_count': 1396, 'Category': 'Bakeries', 'Rating': 3.5, 'Price': '$$', 'Latitude': 37.7618408203125, 'Longitude': -122.41197967529297, 'Review': '[\'Not too sure what took me so long to visit Tartine, specifically this location as their interiors are published on social media every now and then, but...\', \'This place is one of my favorite bakery to go to in the city.\\nGood selection of bread and also this is my first time dine in. On their menu has salad and...\', "We came here at 12:30 pm on a Sunday and easily got bar seating for 2. It\'s a rustic spot, great for casual breakfast and lunch.\\n\\nWe tried the chocolate..."]', 'Rating_binary': 3.5, 'Neighborhood': 'Mission'}
# {'Name': 'Curbside Cafe', 'Review_count': 840, 'Category': 'Breakfast & Brunch', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78868865966797, 'Longitude': -122.43405151367188, 'Review': "['Place was delicious! We got the French onion, steak & risotto \\nService was excellent\\nFood was Twice as good as expected.', 'Charming French place off of Fillmore. We ordered the lamb chops and the crab cake eggs Benedict.  They both were delicious   The lamp chops came with...', 'I went in for breakfast and the server/busser looked extremely busy, barely enough to seat you. There was no hostess outside, so we had to linger inside to...']", 'Rating_binary': 4.0, 'Neighborhood': 'Lower Pacific Heights'}
# {'Name': 'Hardwood Bar & Smokery', 'Review_count': 145, 'Category': 'Sports Bars', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.770450592041016, 'Longitude': -122.40499114990234, 'Review': '[\'Food was hands-down delish! The open and airy atmosphere was very SanFran. Brisket was in point. Well seasoned and tasty. Greens were perfection. Cornbread...\', \'I had the rib plate and spouse had the brisket. Both were excellent.  The sides were both generous and very good. Service was wonderful. We left there...\', "Good BBQ and nice service. I enjoyed the brisket with fries in the outdoor space. It\'s a nice option in the area and I want to come back to try the chicken...."]', 'Rating_binary': 4.0, 'Neighborhood': 'Showplace Square'}
# {'Name': 'Prospect', 'Review_count': 1593, 'Category': 'American (New)', 'Rating': 4.0, 'Price': '$$$', 'Latitude': 37.7898063659668, 'Longitude': -122.39096069335938, 'Review': '["Came here for an after work happy hour / dinner, which seems to be their target crowd (and everything is priced as such). In light of that, it\'s still a...", \'This review is long overdue and written for my two favorite bartenders in San Francisco, Abraham and Jasec! The service that my boyfriend and I receive from...\', "Prospect is an upscale New American restaurant. I came here for a business dinner, so I wasn\'t able to take pictures of all the foods that I sampled. My..."]', 'Rating_binary': 4.0, 'Neighborhood': 'Rincon Hill'}
# {'Name': 'Che Fico', 'Review_count': 615, 'Category': 'Italian', 'Rating': 3.5, 'Price': '$$$', 'Latitude': 37.77743148803711, 'Longitude': -122.4381103515625, 'Review': '[]', 'Rating_binary': 3.5, 'Neighborhood': 'Alamo Square'}
# {'Name': 'Tasty Pot', 'Review_count': 532, 'Category': 'Taiwanese', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78270721435547, 'Longitude': -122.4681167602539, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Hot Zushi', 'Review_count': 182, 'Category': 'Japanese', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.771846771240234, 'Longitude': -122.43096160888672, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Lower Haight'}
# {'Name': "MAC'D", 'Review_count': 371, 'Category': 'Comfort Food', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.796199798583984, 'Longitude': -122.42211151123047, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Polk Gulch'}
# {'Name': 'Sichuan Tasty Restaurant', 'Review_count': 132, 'Category': 'Chinese', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78203582763672, 'Longitude': -122.47901153564453, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'Izakaya Yoki', 'Review_count': 401, 'Category': 'Japanese', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78988265991211, 'Longitude': -122.41231536865234, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Lower Nob Hill'}
# {'Name': 'Queens', 'Review_count': 61, 'Category': 'Grocery', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.7652587890625, 'Longitude': -122.46672058105469, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Inner Sunset'}
# {'Name': 'Cracked & Battered - Potrero Hill', 'Review_count': 1167, 'Category': 'Breakfast & Brunch', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76266098022461, 'Longitude': -122.39718627929688, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Potrero Hill'}
# {'Name': 'Cellarmaker House of Pizza', 'Review_count': 230, 'Category': 'Pizza', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.74573516845703, 'Longitude': -122.41960906982422, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Bernal Heights'}
# {'Name': 'Pacific Cafe', 'Review_count': 801, 'Category': 'Seafood', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.77994155883789, 'Longitude': -122.49456787109375, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Outer Richmond'}
# {'Name': 'MOMO noodle', 'Review_count': 103, 'Category': 'Noodles', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.791053771972656, 'Longitude': -122.40193176269531, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Financial District'}
# {'Name': 'Escape From New York Pizza', 'Review_count': 1217, 'Category': 'Pizza', 'Rating': 4.0, 'Price': '$', 'Latitude': 37.769447326660156, 'Longitude': -122.4512710571289, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Haight Ashbury'}
# {'Name': 'Yoji House', 'Review_count': 130, 'Category': 'Sushi Bars', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.75838851928711, 'Longitude': -122.41954803466797, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Mission'}
# {'Name': 'Karma Cafe', 'Review_count': 88, 'Category': 'Coffee & Tea', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.773590087890625, 'Longitude': -122.44780731201172, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Panhandle'}
# {'Name': 'Wing Lum Cafe', 'Review_count': 75, 'Category': 'Dim Sum', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.78743362426758, 'Longitude': -122.41988372802734, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Lower Nob Hill'}
# {'Name': 'Cafe RX', 'Review_count': 130, 'Category': 'Breakfast & Brunch', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.79985809326172, 'Longitude': -122.45177459716797, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Presidio National Park'}
# {'Name': "Turner's Kitchen", 'Review_count': 386, 'Category': 'Sandwiches', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76308059692383, 'Longitude': -122.42434692382812, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Mission Dolores'}
# {'Name': 'Blush!', 'Review_count': 318, 'Category': 'Wine Bars', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76110076904297, 'Longitude': -122.43518829345703, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Castro'}
# {'Name': 'Warakubune Sushi', 'Review_count': 616, 'Category': 'Conveyor Belt Sushi', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76506042480469, 'Longitude': -122.4287109375, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Mission Dolores'}
# {'Name': 'Flore', 'Review_count': 1141, 'Category': 'Breakfast & Brunch', 'Rating': 3.5, 'Price': '$$', 'Latitude': 37.7646598815918, 'Longitude': -122.43293762207031, 'Review': None, 'Rating_binary': 3.5, 'Neighborhood': 'Duboce Triangle'}
# {'Name': 'Ungrafted', 'Review_count': 151, 'Category': 'American (New)', 'Rating': 4.5, 'Price': '$$$', 'Latitude': 37.75874328613281, 'Longitude': -122.38823699951172, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Dogpatch'}
# {'Name': 'House of Prime Rib', 'Review_count': 8158, 'Category': 'American (Traditional)', 'Rating': 4.0, 'Price': '$$$', 'Latitude': 37.79338073730469, 'Longitude': -122.42250061035156, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Polk Gulch'}
# {'Name': 'Wang Dae Bak', 'Review_count': 337, 'Category': 'Korean', 'Rating': 3.5, 'Price': '$$', 'Latitude': 37.73210144042969, 'Longitude': -122.47386169433594, 'Review': None, 'Rating_binary': 3.5, 'Neighborhood': 'Merced Manor'}
# {'Name': 'Hakashi Japanese Sushi Bar & Grill', 'Review_count': 434, 'Category': 'Sushi Bars', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.7814826965332, 'Longitude': -122.39629364013672, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'South of Market'}
# {'Name': 'Keeva Indian Kitchen', 'Review_count': 663, 'Category': 'Indian', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.78295135498047, 'Longitude': -122.46898651123047, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Inner Richmond'}
# {'Name': 'Barrel Head Brewhouse', 'Review_count': 574, 'Category': 'Breweries', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.775753021240234, 'Longitude': -122.44602966308594, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Panhandle'}
# {'Name': 'LaoTable', 'Review_count': 1339, 'Category': 'Laotian', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.787513732910156, 'Longitude': -122.39871978759766, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'South of Market'}
# {'Name': 'Wooly Pig', 'Review_count': 777, 'Category': 'Sandwiches', 'Rating': 4.5, 'Price': '$$', 'Latitude': 37.76066207885742, 'Longitude': -122.38842010498047, 'Review': None, 'Rating_binary': 4.5, 'Neighborhood': 'Dogpatch'}
# {'Name': 'Boudin', 'Review_count': 4161, 'Category': 'Bakeries', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.80850601196289, 'Longitude': -122.41490173339844, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Fishermans Wharf'}
# {'Name': 'Tara Indian Cuisine', 'Review_count': 421, 'Category': 'Indian', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76540756225586, 'Longitude': -122.43122863769531, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Castro'}
# {'Name': 'Mission Rock Resort', 'Review_count': 1483, 'Category': 'Seafood', 'Rating': 4.0, 'Price': '$$', 'Latitude': 37.76552963256836, 'Longitude': -122.3865966796875, 'Review': None, 'Rating_binary': 4.0, 'Neighborhood': 'Mission Bay'}

# %%
# Create dataframe from imported data
sf_original_df = pd.DataFrame(data)
sf_original_df
# Out:
#                       Name  Review_count      Category  Rating Price  \
# 0           Marufuku Ramen          4122         Ramen     4.5    $$
# 1    Fog Harbor Fish House          8324       Seafood     4.5    $$
# 2           Dumpling House           360       Dim Sum     4.5    $$
# 3                Starbelly          2115  Comfort Food     4.0    $$
# 4                  Bottega           379       Italian     4.5    $$
# ..                     ...           ...           ...     ...   ...
# 619               LaoTable          1339       Laotian     4.0    $$
# 620              Wooly Pig           777    Sandwiches     4.5    $$
# 621                 Boudin          4161      Bakeries     4.0    $$
# 622    Tara Indian Cuisine           421        Indian     4.0    $$
# 623    Mission Rock Resort          1483       Seafood     4.0    $$
#
#       Latitude   Longitude                                             Review  \
# 0    37.785118 -122.432007  ['Long long overdue review, but I loved this p...
# 1    37.808987 -122.410294  ['Great food and not a long wait.  Perfect on ...
# 2    37.763554 -122.432762  ["Love coming here - I've gotten so many of th...
# 3    37.764019 -122.432533  ['Starbelly has been one of my go to comfort r...
# 4    37.754719 -122.421204  ['What a great place to grab lunch/dinner with...
# ..         ...         ...                                                ...
# 619  37.787514 -122.398720                                               None
# 620  37.760662 -122.388420                                               None
# 621  37.808506 -122.414902                                               None
# 622  37.765408 -122.431229                                               None
# 623  37.765530 -122.386597                                               None
#
#      Rating_binary      Neighborhood
# 0              4.5         Japantown
# 1              4.5  Fishermans Wharf
# 2              4.5            Castro
# 3              4.0            Castro
# 4              4.5           Mission
# ..             ...               ...
# 619            4.0   South of Market
# 620            4.5          Dogpatch
# 621            4.0  Fishermans Wharf
# 622            4.0            Castro
# 623            4.0       Mission Bay
#
# [624 rows x 10 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# View a list of all of the columns
sf_original_df.columns
# Out:
# Index(['Name', 'Review_count', 'Category', 'Rating', 'Price', 'Latitude',
#        'Longitude', 'Review', 'Rating_binary', 'Neighborhood'],
#       dtype='object')

# %%
# Check column data types
sf_original_df.dtypes
# Out:
# Name              object
# Review_count       int64
# Category          object
# Rating           float64
# Price             object
# Latitude         float64
# Longitude        float64
# Review            object
# Rating_binary    float64
# Neighborhood      object
# dtype: object

# %%
# Value_counts the Neighborhood column for preprocessing
neighborhood_counts = sf_original_df.Neighborhood.value_counts()
neighborhood_counts
# Out:
# Mission               47
# Inner Richmond        38
# Castro                27
# Inner Sunset          27
# South of Market       27
#                       ..
# Portola                1
# Central Waterfront     1
# Silver Terrace         1
# Eureka Valley          1
# Parnassus Heights      1
# Name: Neighborhood, Length: 71, dtype: int64

# %%
# Display first 30 rows of neighborhood_counts
neighborhood_counts[:30]
# Out:
# Mission                  47
# Inner Richmond           38
# Castro                   27
# Inner Sunset             27
# South of Market          27
# Outer Richmond           25
# Mission Dolores          18
# Lower Nob Hill           17
# Lower Haight             17
# Outer Sunset             16
# Haight Ashbury           16
# Japantown                15
# Financial District       15
# Panhandle                15
# North Beach              14
# Marina                   14
# Lower Pacific Heights    13
# Polk Gulch               13
# Duboce Triangle          12
# Noe Valley               12
# Tenderloin               11
# Pacific Heights          11
# Alamo Square             10
# Fishermans Wharf          9
# Hayes Valley              9
# Presidio Heights          9
# Western Addition          9
# Chinatown                 9
# Civic Center              9
# Union Street              9
# Name: Neighborhood, dtype: int64

# %%
# Visualize the value counts of Neighborhood
neighborhood_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Put the neighborhoods in a list.
neighborhood_list = sf_original_df.Neighborhood.tolist()
neighborhood_list
# Out:
# ['Japantown',
#  'Fishermans Wharf',
#  'Castro',
#  'Castro',
#  'Mission',
#  'Inner Sunset',
#  'Cole Valley',
#  'North Beach',
#  'Castro',
#  'Downtown / Union Square',
#  'Fishermans Wharf',
#  'Pacific Heights',
#  'Mission',
#  'Lower Haight',
#  'Cathedral Hill',
#  'Civic Center',
#  'Inner Sunset',
#  'Mission Dolores',
#  'Duboce Triangle',
#  'Castro',
#  'Japantown',
#  'Outer Richmond',
#  'Haight Ashbury',
#  'Castro',
#  'Outer Sunset',
#  'Inner Richmond',
#  'Outer Richmond',
#  'Alamo Square',
#  'Alamo Square',
#  'Lower Pacific Heights',
#  'Parkside',
#  'Union Street',
#  'Castro',
#  'Japantown',
#  'Panhandle',
#  'Outer Richmond',
#  'Japantown',
#  'Outer Richmond',
#  'North Beach',
#  'Inner Richmond',
#  'Panhandle',
#  'Eureka Valley',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Haight Ashbury',
#  'Pacific Heights',
#  'Western Addition',
#  'South of Market',
#  'Castro',
#  'Castro',
#  'Cole Valley',
#  'Inner Sunset',
#  'Pacific Heights',
#  'Noe Valley',
#  'Presidio Heights',
#  'Panhandle',
#  'Inner Sunset',
#  'Lower Haight',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Mission',
#  'Japantown',
#  'North Beach',
#  'Outer Richmond',
#  'Lower Nob Hill',
#  'Inner Sunset',
#  'Marina',
#  'Portola',
#  'Tenderloin',
#  'Northern Waterfront',
#  'Northern Waterfront',
#  'Haight Ashbury',
#  'Cole Valley',
#  'Mission',
#  'Castro',
#  'Cole Valley',
#  'Castro',
#  'Outer Richmond',
#  'Outer Sunset',
#  'Western Addition',
#  'Noe Valley',
#  'Castro',
#  'Lone Mountain',
#  'Lower Nob Hill',
#  'Inner Sunset',
#  'Hayes Valley',
#  'Inner Richmond',
#  'Marina',
#  'Duboce Triangle',
#  'Union Street',
#  'Mission',
#  'Castro',
#  'Hayes Valley',
#  'Potrero Hill',
#  'Lower Haight',
#  'Financial District',
#  'Lower Pacific Heights',
#  'Lower Haight',
#  'Inner Richmond',
#  'Mission Dolores',
#  'Tenderloin',
#  'Haight Ashbury',
#  'Buena Vista',
#  'Alamo Square',
#  'Duboce Triangle',
#  'Inner Sunset',
#  'Western Addition',
#  'Outer Richmond',
#  'Golden Gate Park',
#  'Panhandle',
#  'Fishermans Wharf',
#  'Inner Richmond',
#  'Marina',
#  'Lower Haight',
#  'Dolores Heights',
#  'Outer Sunset',
#  'Marina',
#  'Outer Sunset',
#  'Inner Richmond',
#  'Panhandle',
#  'Inner Sunset',
#  'Marina',
#  'Duboce Triangle',
#  'North Beach',
#  'Inner Sunset',
#  'Fishermans Wharf',
#  'Inner Richmond',
#  'Japantown',
#  'Tenderloin',
#  'Presidio Heights',
#  'Western Addition',
#  'Duboce Triangle',
#  'Central Waterfront',
#  'Mission',
#  'Lone Mountain',
#  'Hayes Valley',
#  'South of Market',
#  'Pacific Heights',
#  'Japantown',
#  'Aquatic Park / Ft. Mason',
#  'Noe Valley',
#  'Castro',
#  'Lower Nob Hill',
#  'Mission',
#  'Outer Richmond',
#  'Lower Pacific Heights',
#  'South of Market',
#  'Inner Sunset',
#  'Duboce Triangle',
#  'Potrero Hill',
#  'Inner Sunset',
#  'Russian Hill',
#  'Treasure Island',
#  'Showplace Square',
#  'Financial District',
#  'Northern Waterfront',
#  'Castro',
#  'Bernal Heights',
#  'Mission',
#  'Marina',
#  'Inner Richmond',
#  'Haight Ashbury',
#  'Outer Richmond',
#  'Lower Haight',
#  'Mission',
#  'Duboce Triangle',
#  'Noe Valley',
#  'Tenderloin',
#  'Union Street',
#  'Parkside',
#  'Cole Valley',
#  'Lower Nob Hill',
#  'Alamo Square',
#  'Financial District',
#  'Lower Nob Hill',
#  'Tenderloin',
#  'Civic Center',
#  'Presidio Heights',
#  'Mission',
#  'Outer Richmond',
#  'Mission',
#  'Chinatown',
#  'Outer Sunset',
#  'Hayes Valley',
#  'Noe Valley',
#  'Dolores Heights',
#  'South of Market',
#  'Hayes Valley',
#  'Stonestown',
#  'Mission Bay',
#  'Inner Richmond',
#  'North Beach',
#  'Treasure Island',
#  'Mint Hill',
#  'Haight Ashbury',
#  'Outer Richmond',
#  'Dogpatch',
#  'Chinatown',
#  'Lower Pacific Heights',
#  'Inner Richmond',
#  'Inner Richmond',
#  None,
#  'Pacific Heights',
#  'Inner Richmond',
#  'Polk Gulch',
#  'Bernal Heights',
#  'Castro',
#  'Union Street',
#  'Presidio Heights',
#  'Castro',
#  'Dolores Heights',
#  'Outer Sunset',
#  'Outer Richmond',
#  'Lower Haight',
#  'Inner Sunset',
#  'Fishermans Wharf',
#  'Inner Richmond',
#  'South of Market',
#  'Presidio Heights',
#  'Nob Hill',
#  'Noe Valley',
#  'Noe Valley',
#  'Mission Dolores',
#  'Inner Richmond',
#  'Lower Pacific Heights',
#  'Russian Hill',
#  'Mission',
#  'Showplace Square',
#  'Noe Valley',
#  'Inner Richmond',
#  'South of Market',
#  'Mission Dolores',
#  'Mission Bay',
#  'Western Addition',
#  'Inner Richmond',
#  'Presidio National Park',
#  'Silver Terrace',
#  'Outer Sunset',
#  'Parnassus Heights',
#  'Marina',
#  'Mission',
#  'Outer Sunset',
#  'Noe Valley',
#  'Civic Center',
#  'North Beach',
#  'Bernal Heights',
#  'Inner Richmond',
#  'Inner Richmond',
#  'South of Market',
#  'Lower Haight',
#  'Lower Pacific Heights',
#  'North Beach',
#  'Outer Richmond',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Mission',
#  'Parkside',
#  'Cathedral Hill',
#  'Chinatown',
#  'Marina',
#  'Presidio Heights',
#  'Mission',
#  'Inner Richmond',
#  'Panhandle',
#  'Duboce Triangle',
#  'Marina',
#  'Mission',
#  'Inner Sunset',
#  'South of Market',
#  'Lower Pacific Heights',
#  'South Beach',
#  'Marina',
#  'Western Addition',
#  'North Beach',
#  'Japantown',
#  'Pacific Heights',
#  'Presidio Heights',
#  'Mission Dolores',
#  'Financial District',
#  'South of Market',
#  'Haight Ashbury',
#  'Mission Dolores',
#  'Bernal Heights',
#  'Lower Pacific Heights',
#  'Civic Center',
#  'Mission',
#  'Inner Sunset',
#  'Inner Sunset',
#  'Downtown / Union Square',
#  'Crocker Amazon',
#  'Lower Nob Hill',
#  'Castro',
#  'Lower Haight',
#  'Lower Nob Hill',
#  'Castro',
#  'Lower Haight',
#  'Inner Sunset',
#  'Lower Haight',
#  'Western Addition',
#  'Potrero Hill',
#  'North Beach',
#  'South Beach',
#  'Inner Richmond',
#  'Parkside',
#  'Duboce Triangle',
#  'South of Market',
#  'Mission Dolores',
#  'Downtown / Union Square',
#  'Mission',
#  'Aquatic Park / Ft. Mason',
#  'Lower Haight',
#  'Mission',
#  'Noe Valley',
#  'Noe Valley',
#  'Haight Ashbury',
#  'Aquatic Park / Ft. Mason',
#  'Mission',
#  'Castro',
#  'Lower Nob Hill',
#  'Mission',
#  'Inner Richmond',
#  'South of Market',
#  'Inner Richmond',
#  'Haight Ashbury',
#  'Laurel Heights / Jordan Park',
#  'Golden Gate Park',
#  'Financial District',
#  'Financial District',
#  'Bayview',
#  'Mission Dolores',
#  'South of Market',
#  'Hayes Valley',
#  'North Beach',
#  'Financial District',
#  'Dogpatch',
#  'Marina',
#  'Lower Pacific Heights',
#  'Mission',
#  'Inner Richmond',
#  'Panhandle',
#  'North Beach',
#  'Japantown',
#  'Civic Center',
#  'Alamo Square',
#  'Lower Pacific Heights',
#  'Outer Richmond',
#  'South of Market',
#  'Russian Hill',
#  'West Portal',
#  'Inner Sunset',
#  'Pacific Heights',
#  'Haight Ashbury',
#  'Lower Nob Hill',
#  'Mission Bay',
#  'Laurel Heights / Jordan Park',
#  'Japantown',
#  'South Beach',
#  'Financial District',
#  'Haight Ashbury',
#  'Chinatown',
#  'Outer Sunset',
#  'Tenderloin',
#  'Dolores Heights',
#  'North Beach',
#  'Russian Hill',
#  'Inner Sunset',
#  'Dogpatch',
#  'Nob Hill',
#  'South of Market',
#  'Dogpatch',
#  'Japantown',
#  'Union Street',
#  'Marina',
#  'Mission Dolores',
#  'Mission',
#  'Bernal Heights',
#  'Mission',
#  'Mission',
#  'Union Street',
#  'Mission',
#  'Castro',
#  'Lower Haight',
#  'Outer Richmond',
#  'Tenderloin',
#  'Panhandle',
#  'Civic Center',
#  'Haight Ashbury',
#  'Civic Center',
#  'Dolores Heights',
#  'Potrero Hill',
#  'Castro',
#  'Mission Dolores',
#  'Lower Haight',
#  'Cole Valley',
#  'Mission Dolores',
#  'Inner Richmond',
#  'Outer Richmond',
#  'Marina',
#  'South of Market',
#  'West Portal',
#  'Castro',
#  'Inner Richmond',
#  'Aquatic Park / Ft. Mason',
#  'Polk Gulch',
#  'Outer Sunset',
#  'Inner Richmond',
#  'Aquatic Park / Ft. Mason',
#  'Downtown / Union Square',
#  'Outer Richmond',
#  'Polk Gulch',
#  'Mission',
#  'Inner Richmond',
#  'Polk Gulch',
#  'Haight Ashbury',
#  'Mission',
#  'Mission',
#  'Aquatic Park / Ft. Mason',
#  'Inner Sunset',
#  'Panhandle',
#  'Polk Gulch',
#  'Northern Waterfront',
#  'Showplace Square',
#  'Haight Ashbury',
#  'Mission Dolores',
#  'Financial District',
#  'Inner Sunset',
#  'Tenderloin',
#  'Bernal Heights',
#  'Pacific Heights',
#  'Lower Pacific Heights',
#  'Downtown / Union Square',
#  'Inner Richmond',
#  'Alamo Square',
#  'Mission',
#  'Noe Valley',
#  'Outer Sunset',
#  'Fishermans Wharf',
#  'Mission',
#  'Financial District',
#  'Pacific Heights',
#  'Pacific Heights',
#  'West Portal',
#  'Lower Haight',
#  'Polk Gulch',
#  'Tenderloin',
#  'Golden Gate Heights',
#  'Lower Nob Hill',
#  'Apparel City',
#  'Chinatown',
#  'Presidio National Park',
#  'Bernal Heights',
#  'Financial District',
#  'Lower Nob Hill',
#  'Panhandle',
#  'Mission',
#  'Excelsior',
#  'Presidio Heights',
#  'Hayes Valley',
#  'Lower Haight',
#  'Financial District',
#  'Cole Valley',
#  'Japantown',
#  'Duboce Triangle',
#  'Outer Sunset',
#  'Mission Dolores',
#  'Alamo Square',
#  'Outer Sunset',
#  'Alamo Square',
#  'Tenderloin',
#  'Tenderloin',
#  None,
#  'Russian Hill',
#  'Mission',
#  'Showplace Square',
#  'Mission',
#  'Castro',
#  'South of Market',
#  'Northern Waterfront',
#  'Lower Nob Hill',
#  'Civic Center',
#  'Castro',
#  'Chinatown',
#  'Inner Richmond',
#  'Inner Sunset',
#  'Outer Sunset',
#  'Western Addition',
#  'Fairmount',
#  'Japantown',
#  'Mission',
#  'Mission',
#  'Polk Gulch',
#  'Presidio Heights',
#  'Stonestown',
#  'Russian Hill',
#  'Cole Valley',
#  'South of Market',
#  'Mission Dolores',
#  'South of Market',
#  'Mission',
#  'Panhandle',
#  'Alamo Square',
#  'Mission',
#  'Polk Gulch',
#  'Union Street',
#  'Panhandle',
#  'Chinatown',
#  'Polk Gulch',
#  'Mission',
#  'Chinatown',
#  'Mission Bay',
#  'Outer Richmond',
#  None,
#  'Inner Richmond',
#  'Financial District',
#  'Russian Hill',
#  'Outer Richmond',
#  'South of Market',
#  'South of Market',
#  'Civic Center',
#  'Fishermans Wharf',
#  'Polk Gulch',
#  'Mission',
#  'Dolores Heights',
#  'Union Street',
#  'Showplace Square',
#  'Lower Nob Hill',
#  'Outer Richmond',
#  'Mission Bay',
#  'South of Market',
#  'Lower Nob Hill',
#  'Mission',
#  'South of Market',
#  'Duboce Triangle',
#  'Merced Manor',
#  'Chinatown',
#  'Parkmerced',
#  'Outer Richmond',
#  'South of Market',
#  'Cayuga',
#  'Mission',
#  'Lower Nob Hill',
#  'Union Street',
#  'Financial District',
#  'South of Market',
#  'Inner Richmond',
#  'Outer Richmond',
#  'Laurel Heights / Jordan Park',
#  'Lower Pacific Heights',
#  'Mission Dolores',
#  'Dolores Heights',
#  'Inner Sunset',
#  'Pacific Heights',
#  'Mission',
#  'Hayes Valley',
#  'Russian Hill',
#  'Laurel Heights / Jordan Park',
#  'Cathedral Hill',
#  'South of Market',
#  'Fishermans Wharf',
#  'Mission Bay',
#  'North Beach',
#  'Nob Hill',
#  'Merced Manor',
#  'Outer Sunset',
#  'Inner Richmond',
#  'Panhandle',
#  'Polk Gulch',
#  'Haight Ashbury',
#  'Japantown',
#  'Inner Sunset',
#  'Hayes Valley',
#  'Western Addition',
#  'Japantown',
#  'South Beach',
#  'West Portal',
#  'Mission',
#  'Mission Dolores',
#  'Upper Market',
#  None,
#  'Westwood Park',
#  'Outer Sunset',
#  'Inner Richmond',
#  'North Beach',
#  'Marina',
#  'Rincon Hill',
#  'Rincon Hill',
#  'Mission',
#  'Castro',
#  'Outer Richmond',
#  'Mission',
#  'Lower Pacific Heights',
#  'Showplace Square',
#  'Rincon Hill',
#  'Alamo Square',
#  'Inner Richmond',
#  'Lower Haight',
#  'Polk Gulch',
#  'Outer Richmond',
#  'Lower Nob Hill',
#  'Inner Sunset',
#  'Potrero Hill',
#  'Bernal Heights',
#  'Outer Richmond',
#  'Financial District',
#  'Haight Ashbury',
#  'Mission',
#  'Panhandle',
#  'Lower Nob Hill',
#  'Presidio National Park',
#  'Mission Dolores',
#  'Castro',
#  'Mission Dolores',
#  'Duboce Triangle',
#  'Dogpatch',
#  'Polk Gulch',
#  'Merced Manor',
#  'South of Market',
#  'Inner Richmond',
#  'Panhandle',
#  'South of Market',
#  'Dogpatch',
#  'Fishermans Wharf',
#  'Castro',
#  'Mission Bay']

# %%
# Value_counts the Category column for preprocessing
category_counts = sf_original_df.Category.value_counts()
category_counts
# Out:
# American (New)        45
# Italian               40
# Breakfast & Brunch    35
# Japanese              32
# Vietnamese            26
#                       ..
# Uzbek                  1
# Halal                  1
# Gluten-Free            1
# Kebab                  1
# Laotian                1
# Name: Category, Length: 99, dtype: int64

# %%
# Display first 40 rows of category_counts
category_counts[:40]
# Out:
# American (New)            45
# Italian                   40
# Breakfast & Brunch        35
# Japanese                  32
# Vietnamese                26
# Mexican                   25
# Seafood                   23
# Korean                    23
# Chinese                   20
# Sushi Bars                19
# Mediterranean             19
# Pizza                     17
# Coffee & Tea              14
# American (Traditional)    14
# Bakeries                  14
# Ramen                     13
# Thai                      11
# Dim Sum                   10
# Sandwiches                 9
# Burgers                    9
# Cocktail Bars              9
# Noodles                    8
# Wine Bars                  8
# Latin American             8
# Tacos                      7
# Middle Eastern             7
# Burmese                    7
# Asian Fusion               6
# French                     6
# Spanish                    6
# Cafes                      6
# Greek                      5
# Indian                     5
# Chicken Wings              4
# German                     4
# Chicken Shop               4
# Filipino                   3
# Southern                   3
# Japanese Curry             3
# Barbeque                   3
# Name: Category, dtype: int64

# %%
# Visualize the value counts of Category
category_counts.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Put the categories in a list.
cat_list = sf_original_df.Category.tolist()
cat_list
# Out:
# ['Ramen',
#  'Seafood',
#  'Dim Sum',
#  'Comfort Food',
#  'Italian',
#  'Asian Fusion',
#  'Arabic',
#  'Seafood',
#  'Dim Sum',
#  'Thai',
#  'Korean',
#  'Cocktail Bars',
#  'Thai',
#  'Korean',
#  'Sandwiches',
#  'Dim Sum',
#  'Chinese',
#  'Breakfast & Brunch',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Seafood',
#  'Korean',
#  'Latin American',
#  'Vietnamese',
#  'Seafood',
#  'Bakeries',
#  'Pizza',
#  'American (New)',
#  'Cocktail Bars',
#  'American (Traditional)',
#  'Chinese',
#  'Italian',
#  'Mexican',
#  'Japanese',
#  'Mediterranean',
#  'Italian',
#  'Korean',
#  'Mediterranean',
#  'Seafood',
#  'Chinese',
#  'Mexican',
#  'Dim Sum',
#  'Burmese',
#  'Vietnamese',
#  'Caribbean',
#  'Coffee & Tea',
#  'Breakfast & Brunch',
#  'Japanese',
#  'Korean',
#  'Brazilian',
#  'Breakfast & Brunch',
#  'Korean',
#  'Mediterranean',
#  'Mediterranean',
#  'Mediterranean',
#  'Italian',
#  'Korean',
#  'Thai',
#  'Hawaiian',
#  'Mediterranean',
#  'Korean',
#  'Ramen',
#  'Italian',
#  'Taiwanese',
#  'Izakaya',
#  'Persian/Iranian',
#  'Italian',
#  'Diners',
#  'Breakfast & Brunch',
#  'Greek',
#  'Spanish',
#  'Vietnamese',
#  'Mexican',
#  'Izakaya',
#  'American (New)',
#  'Seafood',
#  'Seafood',
#  'Indian',
#  'Breakfast & Brunch',
#  'Tapas/Small Plates',
#  'Chicken Shop',
#  'Vietnamese',
#  'Sushi Bars',
#  'Thai',
#  'Breakfast & Brunch',
#  'Italian',
#  'Tacos',
#  'Breakfast & Brunch',
#  'Dim Sum',
#  'Mexican',
#  'Persian/Iranian',
#  'American (New)',
#  'Greek',
#  'Breakfast & Brunch',
#  'Mexican',
#  'Seafood',
#  'Mediterranean',
#  'Breakfast & Brunch',
#  'Ramen',
#  'Mediterranean',
#  'Italian',
#  'American (Traditional)',
#  'Italian',
#  'Italian',
#  'Arabic',
#  'Ramen',
#  'Caterers',
#  'Korean',
#  'Coffee & Tea',
#  'Poke',
#  'British',
#  'American (Traditional)',
#  'Japanese',
#  'Chinese',
#  'Asian Fusion',
#  'Chinese',
#  'American (New)',
#  'Cocktail Bars',
#  'Cafes',
#  'Bars',
#  'Ramen',
#  'Pizza',
#  'Mexican',
#  'Italian',
#  'Filipino',
#  'Filipino',
#  'Italian',
#  'Japanese',
#  'Chinese',
#  'American (Traditional)',
#  'Bakeries',
#  'Burgers',
#  'Indian',
#  'Wine Bars',
#  'Middle Eastern',
#  'German',
#  'Lounges',
#  'Pizza',
#  'Japanese',
#  'German',
#  'Bakeries',
#  'Sandwiches',
#  'Korean',
#  'Burmese',
#  'Mexican',
#  'Thai',
#  'Speakeasies',
#  'Do-It-Yourself Food',
#  'German',
#  'French',
#  'Italian',
#  'Spanish',
#  'American (Traditional)',
#  'Dim Sum',
#  'Middle Eastern',
#  'Latin American',
#  'Mexican',
#  'Breakfast & Brunch',
#  'Himalayan/Nepalese',
#  'Japanese Curry',
#  'Dim Sum',
#  'Thai',
#  'Middle Eastern',
#  'Japanese',
#  'Italian',
#  'French',
#  'Cafes',
#  'Breakfast & Brunch',
#  'Vietnamese',
#  'Noodles',
#  'Sandwiches',
#  'Coffee & Tea',
#  'Vietnamese',
#  'Japanese',
#  'Ramen',
#  'Food Court',
#  'Ramen',
#  'Italian',
#  'Mexican',
#  'Sandwiches',
#  'American (New)',
#  'Noodles',
#  'Korean',
#  'Wine Bars',
#  'Italian',
#  'Mexican',
#  'Pizza',
#  'French',
#  'Japanese',
#  'Ethiopian',
#  'Vietnamese',
#  'American (New)',
#  'American (New)',
#  'Scandinavian',
#  'Breakfast & Brunch',
#  'Shanghainese',
#  'Italian',
#  'Chinese',
#  'Mediterranean',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Seafood',
#  'Middle Eastern',
#  'Chicken Wings',
#  'Korean',
#  'American (New)',
#  'American (New)',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Italian',
#  'Breakfast & Brunch',
#  'Coffee & Tea',
#  'Italian',
#  'Cafes',
#  'Malaysian',
#  'Seafood',
#  'Japanese',
#  'American (New)',
#  'Vietnamese',
#  'Chicken Wings',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Spanish',
#  'Burmese',
#  'Cafes',
#  'Italian',
#  'Peruvian',
#  'Japanese',
#  'Italian',
#  'Coffee & Tea',
#  'American (New)',
#  'Coffee & Tea',
#  'American (Traditional)',
#  'American (New)',
#  'Greek',
#  'American (New)',
#  'American (New)',
#  'Vietnamese',
#  'Middle Eastern',
#  'Greek',
#  'Ramen',
#  'Bakeries',
#  'Portuguese',
#  'Caribbean',
#  'Seafood',
#  'Hawaiian',
#  'Japanese Curry',
#  'Korean',
#  'Ramen',
#  'American (New)',
#  'Burgers',
#  'Italian',
#  'Dim Sum',
#  'Japanese',
#  'Vietnamese',
#  'Japanese',
#  'Shanghainese',
#  'Japanese',
#  'Asian Fusion',
#  'Seafood',
#  'American (Traditional)',
#  'Steakhouses',
#  'Korean',
#  'Barbeque',
#  'Tacos',
#  'Italian',
#  'Coffee & Tea',
#  'Sports Bars',
#  'Cocktail Bars',
#  'Vietnamese',
#  'Mediterranean',
#  'Noodles',
#  'Mexican',
#  'Wine Bars',
#  'Comfort Food',
#  'Modern European',
#  'American (New)',
#  'Sushi Bars',
#  'Latin American',
#  'Chicken Shop',
#  'American (New)',
#  'Seafood',
#  'Southern',
#  'Bakeries',
#  'Italian',
#  'Mexican',
#  'Sushi Bars',
#  'Noodles',
#  'Sushi Bars',
#  'Chinese',
#  'Sushi Bars',
#  'Sushi Bars',
#  'Mediterranean',
#  'Sushi Bars',
#  'Sushi Bars',
#  'Mediterranean',
#  'Bubble Tea',
#  'Japanese',
#  'Bakeries',
#  'Southern',
#  'Pizza',
#  'Lounges',
#  'Burgers',
#  'Hot Dogs',
#  'Spanish',
#  'Burmese',
#  'Bars',
#  'American (New)',
#  'Japanese',
#  'Mexican',
#  'Italian',
#  'American (New)',
#  'Burmese',
#  'Burgers',
#  'Breakfast & Brunch',
#  'Vegetarian',
#  'Tacos',
#  'Chicken Shop',
#  'Uzbek',
#  'Latin American',
#  'Mexican',
#  'Chinese',
#  'Chinese',
#  'Halal',
#  'Chicken Wings',
#  'Breweries',
#  'American (New)',
#  'Mediterranean',
#  'Coffee & Tea',
#  'Bakeries',
#  'Diners',
#  'Mexican',
#  'Cocktail Bars',
#  'Latin American',
#  'Brazilian',
#  'Breakfast & Brunch',
#  'Mexican',
#  'Gluten-Free',
#  'Kebab',
#  'Mediterranean',
#  'Pizza',
#  'Japanese',
#  'Vietnamese',
#  'Japanese',
#  'Sushi Bars',
#  'Vietnamese',
#  'Japanese',
#  'Mediterranean',
#  'Chicken Wings',
#  'Bakeries',
#  'Wine Bars',
#  'Gastropubs',
#  'Mexican',
#  'American (Traditional)',
#  'Italian',
#  'Sushi Bars',
#  'Asian Fusion',
#  'Vietnamese',
#  'Sushi Bars',
#  'Barbeque',
#  'Pizza',
#  'American (New)',
#  'Breakfast & Brunch',
#  'Asian Fusion',
#  'Breakfast & Brunch',
#  'Indian',
#  'Italian',
#  'American (New)',
#  'Ethiopian',
#  'Latin American',
#  'Hawaiian',
#  'American (New)',
#  'American (New)',
#  'Poke',
#  'Caribbean',
#  'American (New)',
#  'Italian',
#  'Noodles',
#  'American (New)',
#  'Spanish',
#  'Mediterranean',
#  'German',
#  'Chinese',
#  'Korean',
#  'Coffee & Tea',
#  'Salad',
#  'Pizza',
#  'Gastropubs',
#  'Mexican',
#  'Food Trucks',
#  'Vietnamese',
#  'Thai',
#  'Ramen',
#  'Pizza',
#  'Korean',
#  'Tacos',
#  'Vietnamese',
#  'Thai',
#  'Burgers',
#  'Latin American',
#  'American (Traditional)',
#  'Bakeries',
#  'American (New)',
#  'Seafood',
#  'Chinese',
#  'Malaysian',
#  'Bars',
#  'American (New)',
#  'Chinese',
#  'Korean',
#  'Cuban',
#  'Teppanyaki',
#  'Salad',
#  'Breakfast & Brunch',
#  'Japanese',
#  'American (New)',
#  'American (New)',
#  'Creperies',
#  'Japanese',
#  'Cocktail Bars',
#  'Cajun/Creole',
#  'Spanish',
#  'Mexican',
#  'Greek',
#  'Latin American',
#  'Cafes',
#  'Vietnamese',
#  'Vietnamese',
#  'Cafes',
#  'Pizza',
#  'Japanese',
#  'American (New)',
#  'Pizza',
#  'Guamanian',
#  'Sushi Bars',
#  'Chinese',
#  'American (New)',
#  'Pizza',
#  'Ukrainian',
#  'Italian',
#  'French',
#  'Middle Eastern',
#  'Coffee & Tea',
#  'Mexican',
#  'Korean',
#  'Chinese',
#  'Hot Pot',
#  'Japanese',
#  'Bakeries',
#  'American (New)',
#  'Himalayan/Nepalese',
#  'Japanese',
#  'Korean',
#  'Italian',
#  'Cajun/Creole',
#  'Filipino',
#  'American (New)',
#  'French',
#  'Sushi Bars',
#  'Vietnamese',
#  'Italian',
#  'Ramen',
#  'Mexican',
#  'Vietnamese',
#  'Chinese',
#  'Sandwiches',
#  'Korean',
#  'Breakfast & Brunch',
#  'Poke',
#  'Cocktail Bars',
#  'American (Traditional)',
#  'Italian',
#  'Ramen',
#  'Burmese',
#  'Japanese',
#  'Diners',
#  'Breakfast & Brunch',
#  'American (New)',
#  'Sushi Bars',
#  'Bakeries',
#  'Cocktail Bars',
#  'Korean',
#  'French',
#  'Barbeque',
#  'Thai',
#  'Coffee & Tea',
#  'Seafood',
#  'Thai',
#  'Burmese',
#  'Izakaya',
#  'Breakfast & Brunch',
#  'Italian',
#  'Szechuan',
#  'Pizza',
#  'Pubs',
#  'Vietnamese',
#  'Sushi Bars',
#  'Mexican',
#  'Breakfast & Brunch',
#  'Salvadoran',
#  'American (Traditional)',
#  'Mexican',
#  'Breakfast & Brunch',
#  'Mexican',
#  'Salvadoran',
#  'Coffee & Tea',
#  'Japanese',
#  'Peruvian',
#  'Cantonese',
#  'Food Trucks',
#  'Vietnamese',
#  'Fish & Chips',
#  'Vietnamese',
#  'Italian',
#  'Breakfast & Brunch',
#  'American (Traditional)',
#  'Wine Bars',
#  'Food Stands',
#  'Pizza',
#  'Cajun/Creole',
#  'Mediterranean',
#  'Nicaraguan',
#  'Juice Bars & Smoothies',
#  'Asian Fusion',
#  'Sushi Bars',
#  'Breakfast & Brunch',
#  'Vietnamese',
#  'Noodles',
#  'Szechuan',
#  'Coffee & Tea',
#  'Mexican',
#  'American (New)',
#  'Mediterranean',
#  'Japanese',
#  'Japanese Curry',
#  'Dim Sum',
#  'Soul Food',
#  'Breakfast & Brunch',
#  'Southern',
#  'Caterers',
#  'Japanese',
#  'Tacos',
#  'American (Traditional)',
#  'Breakfast & Brunch',
#  'Sandwiches',
#  'Burgers',
#  'Burgers',
#  'Sandwiches',
#  'Japanese',
#  'Vietnamese',
#  'Chinese',
#  'Italian',
#  'Bakeries',
#  'Chicken Shop',
#  'Wine Bars',
#  'Burgers',
#  'American (New)',
#  'Japanese',
#  'Seafood',
#  'Tacos',
#  'Italian',
#  'Italian',
#  'American (New)',
#  'Noodles',
#  'Burgers',
#  'Seafood',
#  'Ramen',
#  'Pizza',
#  'American (New)',
#  'Chinese',
#  'Sushi Bars',
#  'Chinese',
#  'Wine Bars',
#  'Tacos',
#  'Steakhouses',
#  'Middle Eastern',
#  'Mediterranean',
#  'Thai',
#  'Seafood',
#  'Korean',
#  'Vietnamese',
#  'Italian',
#  'Italian',
#  'Cocktail Bars',
#  'Seafood',
#  'Seafood',
#  'Seafood',
#  'Delis',
#  'Japanese',
#  'Bakeries',
#  'Breakfast & Brunch',
#  'Sports Bars',
#  'American (New)',
#  'Italian',
#  'Taiwanese',
#  'Japanese',
#  'Comfort Food',
#  'Chinese',
#  'Japanese',
#  'Grocery',
#  'Breakfast & Brunch',
#  'Pizza',
#  'Seafood',
#  'Noodles',
#  'Pizza',
#  'Sushi Bars',
#  'Coffee & Tea',
#  'Dim Sum',
#  'Breakfast & Brunch',
#  'Sandwiches',
#  'Wine Bars',
#  'Conveyor Belt Sushi',
#  'Breakfast & Brunch',
#  'American (New)',
#  'American (Traditional)',
#  'Korean',
#  'Sushi Bars',
#  'Indian',
#  'Breweries',
#  'Laotian',
#  'Sandwiches',
#  'Bakeries',
#  'Indian',
#  'Seafood']

# %%
# Create dataframe with just thai, indian, and asian fusion restaurants
target_cuisines = sf_original_df.loc[sf_original_df.apply(
    lambda x: x.Category in ["Asian Fusion","Indian","Thai"], axis=1)]
target_cuisines
# Out:
#                                Name  Review_count      Category  Rating Price  \
# 5                     Jamie's Place           242  Asian Fusion     4.5    $$
# 9                          Kin Khao          2148          Thai     4.0    $$
# 12   Farmhouse Kitchen Thai Cuisine          3388          Thai     4.0    $$
# 57                 Mangrove Kitchen           349          Thai     4.0    $$
# 77             Ocean Indian Cuisine           254        Indian     5.0    $$
# 83                    Ben Thai Cafe           759          Thai     4.5    $$
# 114                          Alnico           404  Asian Fusion     4.5    $$
# 132                        Besharam           355        Indian     4.0    $$
# 145         Sweet Lime Thai Cuisine           556          Thai     4.0    $$
# 161         What The Cluck - Haight           229          Thai     4.5    $$
# 258                Spork Restaurant           122  Asian Fusion     5.0    $$
# 356                             HRD          2536  Asian Fusion     4.0    $$
# 363                   Chubby Noodle           894  Asian Fusion     4.0    $$
# 365             Rose Indian Cuisine           431        Indian     4.5    $$
# 391                Gai Chicken Rice           339          Thai     4.0    $$
# 397                       Blackwood          2006          Thai     4.0    $$
# 484                     Marnee Thai          1932          Thai     4.0    $$
# 487                            Nari           274          Thai     4.0   $$$
# 523                  Dumpling Union           129  Asian Fusion     4.5    $$
# 577           Rin's Thai Restaurant           393          Thai     4.0    $$
# 617            Keeva Indian Kitchen           663        Indian     4.5    $$
# 622             Tara Indian Cuisine           421        Indian     4.0    $$
#
#       Latitude   Longitude                                             Review  \
# 5    37.762615 -122.465981  ['Very good food and service is very friendly....
# 9    37.785240 -122.409332  ["I'll start with saying the only reason it's ...
# 12   37.760193 -122.411415  ['Food was good, good portiond, service was go...
# 57   37.772511 -122.436958  ['Great food. Amazing atmosphere and phenomena...
# 77   37.779900 -122.485222  ['My friend and I initially stopped here for a...
# 83   37.789242 -122.420647  ['Very good food. I got the Salmon Delight wit...
# 114  37.755951 -122.421326  ['10/10 for brunch!\n-Steak and Eggs is my fav...
# 132  37.754196 -122.389732  ["This place is great and will definitely be b...
# 145  37.786003 -122.435127  ['My husband and I were looking for the perfec...
# 161  37.769531 -122.451576  ["Love this place for a quick meal and it's he...
# 258  37.797676 -122.407532  ['The chicken and pandan waffle was amazing - ...
# 356  37.781105 -122.395332  ['Delicious burritos! Had the Spicy Pork and t...
# 363  37.799763 -122.408569  ['This is a great spot to brunch!! Our waitres...
# 365  37.762470 -122.465912  ["Simply put, we both thought this was maybe t...
# 391  37.764198 -122.429977  ['Delicious and healthy meal. Great for kids o...
# 397  37.800591 -122.438835  ["This is THE place to visit if you're looking...
# 484  37.763111 -122.481796  ['Family style Thai restaurant tucked in betwe...
# 487  37.785431 -122.428276  ['All dishes are definitely on the spicier end...
# 523  37.797729 -122.429161  ['The new dumpling spot is really good\n\nThes...
# 577  37.750946 -122.438599  ['I have only had their red curry with chicken...
# 617  37.782951 -122.468987                                               None
# 622  37.765408 -122.431229                                               None
#
#      Rating_binary             Neighborhood
# 5              4.5             Inner Sunset
# 9              4.0  Downtown / Union Square
# 12             4.0                  Mission
# 57             4.0             Lower Haight
# 77             5.0           Outer Richmond
# 83             4.5           Lower Nob Hill
# 114            4.5          Dolores Heights
# 132            4.0       Central Waterfront
# 145            4.0    Lower Pacific Heights
# 161            4.5           Haight Ashbury
# 258            5.0                Chinatown
# 356            4.0              South Beach
# 363            4.0              North Beach
# 365            4.5             Inner Sunset
# 391            4.0          Mission Dolores
# 397            4.0                   Marina
# 484            4.0             Outer Sunset
# 487            4.0                Japantown
# 523            4.5             Union Street
# 577            4.0             Upper Market
# 617            4.5           Inner Richmond
# 622            4.0                   Castro

# %%
# Create a list of the target cuisine row index values
target_index = target_cuisines.index.values.tolist()
target_index
# Out:
# [5,
#  9,
#  12,
#  57,
#  77,
#  83,
#  114,
#  132,
#  145,
#  161,
#  258,
#  356,
#  363,
#  365,
#  391,
#  397,
#  484,
#  487,
#  523,
#  577,
#  617,
#  622]

# %%
# Plot the target_cuisines 'Rating' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Rating", y="Name", data=target_cuisines, ax=ax).set(title='Target Cuisine Restaurant Ratings')
plt.show()

# %%
# Plot the target_cuisines 'Review_count' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Review_count", y="Name", data=target_cuisines, ax=ax).set(title='Target Cuisine Restaurant Review Counts')
plt.show()

# %%
# Value_counts the Price column for preprocessing
price_counts = sf_original_df.Price.value_counts()
print(price_counts)
# Out:
# $$      501
# $$$      67
# $        35
# $$$$     21
# Name: Price, dtype: int64

# %%
# Plot the 'Rating' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Rating", y="Name", data=sf_original_df, ax=ax).set(title='Restaurant Ratings')
plt.show()

# %%
# Plot the 'Rating' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Rating", y="Name", data=sf_original_df[:20], ax=ax).set(title='Sampling of Restaurant Ratings')
plt.show()

# %%
# Plot the 'Review_count' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Review_count", y="Name", data=sf_original_df, ax=ax).set(title='Restaurant Review Counts')
plt.show()

# %%
# Plot the 'Review_count' and the 'Name' columns in a barplot.
fig, ax = plt.subplots(figsize=(8,9))
sns.barplot(x="Review_count", y="Name", data=sf_original_df[:20], ax=ax).set(title='Sampling of Restaurant Review Counts')
plt.show()

# %%
# Plot the 'Rating' in a countplot.
fig, ax = plt.subplots(figsize=(10,7))
sns.countplot(sf_original_df["Rating"], ax=ax)
plt.title("Restaurant Rating Countplot")
plt.show()
# Out:
# C:\Users\Michelle\anaconda3\envs\mlenv\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## Preprocess the data

# %%
# Drop columns that are not relevant to the analysis / will confuse the model
sf_df = sf_original_df.drop(columns=[
    'Name',
    'Latitude',
    'Longitude',
    'Review'
    ])
sf_df.head()
# Out:
#    Review_count      Category  Rating Price  Rating_binary      Neighborhood
# 0          4122         Ramen     4.5    $$            4.5         Japantown
# 1          8324       Seafood     4.5    $$            4.5  Fishermans Wharf
# 2           360       Dim Sum     4.5    $$            4.5            Castro
# 3          2115  Comfort Food     4.0    $$            4.0            Castro
# 4           379       Italian     4.5    $$            4.5           Mission

# %%
# Convert 'Rating_binary' column to binary values
sf_df.loc[sf_df["Rating_binary"] < 4, "Rating_binary"] = 0
sf_df.loc[sf_df["Rating_binary"] >= 4, "Rating_binary"] = 1
sf_df
# Out:
#      Review_count      Category  Rating Price  Rating_binary      Neighborhood
# 0            4122         Ramen     4.5    $$            1.0         Japantown
# 1            8324       Seafood     4.5    $$            1.0  Fishermans Wharf
# 2             360       Dim Sum     4.5    $$            1.0            Castro
# 3            2115  Comfort Food     4.0    $$            1.0            Castro
# 4             379       Italian     4.5    $$            1.0           Mission
# ..            ...           ...     ...   ...            ...               ...
# 619          1339       Laotian     4.0    $$            1.0   South of Market
# 620           777    Sandwiches     4.5    $$            1.0          Dogpatch
# 621          4161      Bakeries     4.0    $$            1.0  Fishermans Wharf
# 622           421        Indian     4.0    $$            1.0            Castro
# 623          1483       Seafood     4.0    $$            1.0       Mission Bay
#
# [624 rows x 6 columns]

# %%
# Convert 'Rating_binary' column from float64 to int to get rid of the decimal
sf_df = sf_df.astype({'Rating_binary' : int})
sf_df.head()
# Out:
#    Review_count      Category  Rating Price  Rating_binary      Neighborhood
# 0          4122         Ramen     4.5    $$              1         Japantown
# 1          8324       Seafood     4.5    $$              1  Fishermans Wharf
# 2           360       Dim Sum     4.5    $$              1            Castro
# 3          2115  Comfort Food     4.0    $$              1            Castro
# 4           379       Italian     4.5    $$              1           Mission

# %%
# Drop the Rating column since the Rating binary column is what we will use for the analysis
sf_df = sf_df.drop(columns=['Rating'])
sf_df.head()
# Out:
#    Review_count      Category Price  Rating_binary      Neighborhood
# 0          4122         Ramen    $$              1         Japantown
# 1          8324       Seafood    $$              1  Fishermans Wharf
# 2           360       Dim Sum    $$              1            Castro
# 3          2115  Comfort Food    $$              1            Castro
# 4           379       Italian    $$              1           Mission

# %%
# Convert 'Price' column to numeric values
sf_df.loc[sf_df["Price"] == "$", "Price"] = 1
sf_df.loc[sf_df["Price"] == "$$", "Price"] = 2
sf_df.loc[sf_df["Price"] == "$$$", "Price"] = 3
sf_df.loc[sf_df["Price"] == "$$$$", "Price"] = 4
sf_df
# Out:
#      Review_count      Category Price  Rating_binary      Neighborhood
# 0            4122         Ramen     2              1         Japantown
# 1            8324       Seafood     2              1  Fishermans Wharf
# 2             360       Dim Sum     2              1            Castro
# 3            2115  Comfort Food     2              1            Castro
# 4             379       Italian     2              1           Mission
# ..            ...           ...   ...            ...               ...
# 619          1339       Laotian     2              1   South of Market
# 620           777    Sandwiches     2              1          Dogpatch
# 621          4161      Bakeries     2              1  Fishermans Wharf
# 622           421        Indian     2              1            Castro
# 623          1483       Seafood     2              1       Mission Bay
#
# [624 rows x 5 columns]

# %% [markdown]
# #### Bin the Category column

# %%
# Display the Category value counts
cat_counts = sf_df.Category.value_counts()
cat_counts[:40]
# Out:
# American (New)            45
# Italian                   40
# Breakfast & Brunch        35
# Japanese                  32
# Vietnamese                26
# Mexican                   25
# Seafood                   23
# Korean                    23
# Chinese                   20
# Sushi Bars                19
# Mediterranean             19
# Pizza                     17
# Coffee & Tea              14
# American (Traditional)    14
# Bakeries                  14
# Ramen                     13
# Thai                      11
# Dim Sum                   10
# Sandwiches                 9
# Burgers                    9
# Cocktail Bars              9
# Noodles                    8
# Wine Bars                  8
# Latin American             8
# Tacos                      7
# Middle Eastern             7
# Burmese                    7
# Asian Fusion               6
# French                     6
# Spanish                    6
# Cafes                      6
# Greek                      5
# Indian                     5
# Chicken Wings              4
# German                     4
# Chicken Shop               4
# Filipino                   3
# Southern                   3
# Japanese Curry             3
# Barbeque                   3
# Name: Category, dtype: int64

# %%
# Determine which values to replace if counts are less than ...?
replace_category = list(cat_counts[cat_counts <= 4].index)

# Replace in dataframe
for cat in replace_category:
    sf_df.Category = sf_df.Category.replace(cat,"Other")
    
# Check to make sure binning was successful
cat_counts2 = sf_df.Category.value_counts()
cat_counts2[:40]
# Out:
# Other                     118
# American (New)             45
# Italian                    40
# Breakfast & Brunch         35
# Japanese                   32
# Vietnamese                 26
# Mexican                    25
# Korean                     23
# Seafood                    23
# Chinese                    20
# Sushi Bars                 19
# Mediterranean              19
# Pizza                      17
# American (Traditional)     14
# Coffee & Tea               14
# Bakeries                   14
# Ramen                      13
# Thai                       11
# Dim Sum                    10
# Sandwiches                  9
# Cocktail Bars               9
# Burgers                     9
# Latin American              8
# Wine Bars                   8
# Noodles                     8
# Tacos                       7
# Burmese                     7
# Middle Eastern              7
# Spanish                     6
# Cafes                       6
# Asian Fusion                6
# French                      6
# Greek                       5
# Indian                      5
# Name: Category, dtype: int64

# %%
# Determine which values to replace if counts are less than ...?
replace_category2 = list(cat_counts2[(cat_counts2 <= 10) & (cat_counts2 > 5)].index)

# Replace in dataframe
for cat in replace_category2:
    sf_df.Category = sf_df.Category.replace(cat,"Other")
    
# Check to make sure binning was successful
cat_counts3 = sf_df.Category.value_counts()
cat_counts3[:20]
# Out:
# Other                     224
# American (New)             45
# Italian                    40
# Breakfast & Brunch         35
# Japanese                   32
# Vietnamese                 26
# Mexican                    25
# Korean                     23
# Seafood                    23
# Chinese                    20
# Sushi Bars                 19
# Mediterranean              19
# Pizza                      17
# Coffee & Tea               14
# Bakeries                   14
# American (Traditional)     14
# Ramen                      13
# Thai                       11
# Greek                       5
# Indian                      5
# Name: Category, dtype: int64

# %%
# Display the dataframe to check the binning changes
sf_df
# Out:
#      Review_count  Category Price  Rating_binary      Neighborhood
# 0            4122     Ramen     2              1         Japantown
# 1            8324   Seafood     2              1  Fishermans Wharf
# 2             360     Other     2              1            Castro
# 3            2115     Other     2              1            Castro
# 4             379   Italian     2              1           Mission
# ..            ...       ...   ...            ...               ...
# 619          1339     Other     2              1   South of Market
# 620           777     Other     2              1          Dogpatch
# 621          4161  Bakeries     2              1  Fishermans Wharf
# 622           421    Indian     2              1            Castro
# 623          1483   Seafood     2              1       Mission Bay
#
# [624 rows x 5 columns]

# %% [markdown]
# #### Prepare sf_df for export to .csv and .json files for use on visualization dashboard

# %%
# Copy the sf_df to prepare dataframe for file export
sf_export_df = sf_df.copy()
sf_export_df
# Out:
#      Review_count  Category Price  Rating_binary      Neighborhood
# 0            4122     Ramen     2              1         Japantown
# 1            8324   Seafood     2              1  Fishermans Wharf
# 2             360     Other     2              1            Castro
# 3            2115     Other     2              1            Castro
# 4             379   Italian     2              1           Mission
# ..            ...       ...   ...            ...               ...
# 619          1339     Other     2              1   South of Market
# 620           777     Other     2              1          Dogpatch
# 621          4161  Bakeries     2              1  Fishermans Wharf
# 622           421    Indian     2              1            Castro
# 623          1483   Seafood     2              1       Mission Bay
#
# [624 rows x 5 columns]

# %%
# Add columns back for use with visualizations
sf_export_df["Name"] = sf_original_df['Name']
sf_export_df["Latitude"] = sf_original_df['Latitude']
sf_export_df["Longitude"] = sf_original_df['Longitude']
sf_export_df["Review"] = sf_original_df['Review']
sf_export_df["Rating"] = sf_original_df['Rating']
sf_export_df
# Out:
#      Review_count  Category Price  Rating_binary      Neighborhood  \
# 0            4122     Ramen     2              1         Japantown
# 1            8324   Seafood     2              1  Fishermans Wharf
# 2             360     Other     2              1            Castro
# 3            2115     Other     2              1            Castro
# 4             379   Italian     2              1           Mission
# ..            ...       ...   ...            ...               ...
# 619          1339     Other     2              1   South of Market
# 620           777     Other     2              1          Dogpatch
# 621          4161  Bakeries     2              1  Fishermans Wharf
# 622           421    Indian     2              1            Castro
# 623          1483   Seafood     2              1       Mission Bay
#
#                       Name   Latitude   Longitude  \
# 0           Marufuku Ramen  37.785118 -122.432007
# 1    Fog Harbor Fish House  37.808987 -122.410294
# 2           Dumpling House  37.763554 -122.432762
# 3                Starbelly  37.764019 -122.432533
# 4                  Bottega  37.754719 -122.421204
# ..                     ...        ...         ...
# 619               LaoTable  37.787514 -122.398720
# 620              Wooly Pig  37.760662 -122.388420
# 621                 Boudin  37.808506 -122.414902
# 622    Tara Indian Cuisine  37.765408 -122.431229
# 623    Mission Rock Resort  37.765530 -122.386597
#
#                                                 Review  Rating
# 0    ['Long long overdue review, but I loved this p...     4.5
# 1    ['Great food and not a long wait.  Perfect on ...     4.5
# 2    ["Love coming here - I've gotten so many of th...     4.5
# 3    ['Starbelly has been one of my go to comfort r...     4.0
# 4    ['What a great place to grab lunch/dinner with...     4.5
# ..                                                 ...     ...
# 619                                               None     4.0
# 620                                               None     4.5
# 621                                               None     4.0
# 622                                               None     4.0
# 623                                               None     4.0
#
# [624 rows x 10 columns]

# %%
# Drop columns that are not relevant to the visualization
sf_export_df = sf_export_df.drop(columns=[
    'Rating_binary'
    ])
sf_export_df
# Out:
#      Review_count  Category Price      Neighborhood                   Name  \
# 0            4122     Ramen     2         Japantown         Marufuku Ramen
# 1            8324   Seafood     2  Fishermans Wharf  Fog Harbor Fish House
# 2             360     Other     2            Castro         Dumpling House
# 3            2115     Other     2            Castro              Starbelly
# 4             379   Italian     2           Mission                Bottega
# ..            ...       ...   ...               ...                    ...
# 619          1339     Other     2   South of Market               LaoTable
# 620           777     Other     2          Dogpatch              Wooly Pig
# 621          4161  Bakeries     2  Fishermans Wharf                 Boudin
# 622           421    Indian     2            Castro    Tara Indian Cuisine
# 623          1483   Seafood     2       Mission Bay    Mission Rock Resort
#
#       Latitude   Longitude                                             Review  \
# 0    37.785118 -122.432007  ['Long long overdue review, but I loved this p...
# 1    37.808987 -122.410294  ['Great food and not a long wait.  Perfect on ...
# 2    37.763554 -122.432762  ["Love coming here - I've gotten so many of th...
# 3    37.764019 -122.432533  ['Starbelly has been one of my go to comfort r...
# 4    37.754719 -122.421204  ['What a great place to grab lunch/dinner with...
# ..         ...         ...                                                ...
# 619  37.787514 -122.398720                                               None
# 620  37.760662 -122.388420                                               None
# 621  37.808506 -122.414902                                               None
# 622  37.765408 -122.431229                                               None
# 623  37.765530 -122.386597                                               None
#
#      Rating
# 0       4.5
# 1       4.5
# 2       4.5
# 3       4.0
# 4       4.5
# ..      ...
# 619     4.0
# 620     4.5
# 621     4.0
# 622     4.0
# 623     4.0
#
# [624 rows x 9 columns]

# %%
# Reorder the sf_export_df columns
sf_export_df = sf_export_df[['Name', 
                             'Category', 
                             'Price', 
                             'Rating', 
                             'Review_count', 
                             'Review', 
                             'Neighborhood',
                             'Latitude',
                             'Longitude']]
sf_export_df
# Out:
#                       Name  Category Price  Rating  Review_count  \
# 0           Marufuku Ramen     Ramen     2     4.5          4122
# 1    Fog Harbor Fish House   Seafood     2     4.5          8324
# 2           Dumpling House     Other     2     4.5           360
# 3                Starbelly     Other     2     4.0          2115
# 4                  Bottega   Italian     2     4.5           379
# ..                     ...       ...   ...     ...           ...
# 619               LaoTable     Other     2     4.0          1339
# 620              Wooly Pig     Other     2     4.5           777
# 621                 Boudin  Bakeries     2     4.0          4161
# 622    Tara Indian Cuisine    Indian     2     4.0           421
# 623    Mission Rock Resort   Seafood     2     4.0          1483
#
#                                                 Review      Neighborhood  \
# 0    ['Long long overdue review, but I loved this p...         Japantown
# 1    ['Great food and not a long wait.  Perfect on ...  Fishermans Wharf
# 2    ["Love coming here - I've gotten so many of th...            Castro
# 3    ['Starbelly has been one of my go to comfort r...            Castro
# 4    ['What a great place to grab lunch/dinner with...           Mission
# ..                                                 ...               ...
# 619                                               None   South of Market
# 620                                               None          Dogpatch
# 621                                               None  Fishermans Wharf
# 622                                               None            Castro
# 623                                               None       Mission Bay
#
#       Latitude   Longitude
# 0    37.785118 -122.432007
# 1    37.808987 -122.410294
# 2    37.763554 -122.432762
# 3    37.764019 -122.432533
# 4    37.754719 -122.421204
# ..         ...         ...
# 619  37.787514 -122.398720
# 620  37.760662 -122.388420
# 621  37.808506 -122.414902
# 622  37.765408 -122.431229
# 623  37.765530 -122.386597
#
# [624 rows x 9 columns]

# %%
# Export the information to a CSV file
sf_export_df.to_csv('Export_files/SF_Data_binned.csv',index=False,header=True)

# %%
# Export the information to a JSON file
sf_export_df.to_json('Export_files/SF_Data_binned.json')

# %% [markdown]
# #### Back to data preprocessing:
# #### Bin the Neighborhood column

# %%
# Get the Neighborhood column value counts
neighbor_counts = sf_df.Neighborhood.value_counts()
neighbor_counts[:40]
# Out:
# Mission                     47
# Inner Richmond              38
# Castro                      27
# Inner Sunset                27
# South of Market             27
# Outer Richmond              25
# Mission Dolores             18
# Lower Nob Hill              17
# Lower Haight                17
# Outer Sunset                16
# Haight Ashbury              16
# Japantown                   15
# Financial District          15
# Panhandle                   15
# North Beach                 14
# Marina                      14
# Lower Pacific Heights       13
# Polk Gulch                  13
# Duboce Triangle             12
# Noe Valley                  12
# Tenderloin                  11
# Pacific Heights             11
# Alamo Square                10
# Fishermans Wharf             9
# Hayes Valley                 9
# Presidio Heights             9
# Western Addition             9
# Chinatown                    9
# Civic Center                 9
# Union Street                 9
# Bernal Heights               8
# Russian Hill                 8
# Cole Valley                  8
# Mission Bay                  7
# Dolores Heights              7
# Dogpatch                     6
# Showplace Square             6
# Aquatic Park / Ft. Mason     6
# Potrero Hill                 5
# Northern Waterfront          5
# Name: Neighborhood, dtype: int64

# %%
# Determine which values to replace if counts are less than ...?
replace_neighborhood = list(neighbor_counts[neighbor_counts < 9].index)

# Replace in dataframe
for app in replace_neighborhood:
    sf_df.Neighborhood = sf_df.Neighborhood.replace(app,"Other")
    
# Check to make sure binning was successful
neighbor_counts2 = sf_df.Neighborhood.value_counts()
neighbor_counts2[:31]
# Out:
# Other                    127
# Mission                   47
# Inner Richmond            38
# Castro                    27
# Inner Sunset              27
# South of Market           27
# Outer Richmond            25
# Mission Dolores           18
# Lower Nob Hill            17
# Lower Haight              17
# Outer Sunset              16
# Haight Ashbury            16
# Financial District        15
# Panhandle                 15
# Japantown                 15
# Marina                    14
# North Beach               14
# Lower Pacific Heights     13
# Polk Gulch                13
# Duboce Triangle           12
# Noe Valley                12
# Pacific Heights           11
# Tenderloin                11
# Alamo Square              10
# Fishermans Wharf           9
# Union Street               9
# Western Addition           9
# Civic Center               9
# Presidio Heights           9
# Hayes Valley               9
# Chinatown                  9
# Name: Neighborhood, dtype: int64

# %%
# Display the dataframe to check the binning changes
sf_df
# Out:
#      Review_count  Category Price  Rating_binary      Neighborhood
# 0            4122     Ramen     2              1         Japantown
# 1            8324   Seafood     2              1  Fishermans Wharf
# 2             360     Other     2              1            Castro
# 3            2115     Other     2              1            Castro
# 4             379   Italian     2              1           Mission
# ..            ...       ...   ...            ...               ...
# 619          1339     Other     2              1   South of Market
# 620           777     Other     2              1             Other
# 621          4161  Bakeries     2              1  Fishermans Wharf
# 622           421    Indian     2              1            Castro
# 623          1483   Seafood     2              1             Other
#
# [624 rows x 5 columns]

# %% [markdown]
# ### Define variables and Split the data into train and test sets

# %%
# Create our features
X = sf_df.drop(columns="Rating_binary")
X = pd.get_dummies(X)


# Create our target
y = sf_df["Rating_binary"]

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Check the shape of X_train
X_train.shape
# Out:
# (468, 56)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Create, Train, and Evaluate the model

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs", max_iter=200, random_state=1)


# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic Regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")

results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(20)
# Out:
#  Logistic Regression model accuracy: 0.949
#     Prediction  Actual
# 0            1       1
# 1            1       1
# 2            1       1
# 3            1       1
# 4            1       1
# 5            1       1
# 6            1       0
# 7            1       1
# 8            1       1
# 9            1       1
# 10           1       1
# 11           1       1
# 12           1       1
# 13           1       1
# 14           1       1
# 15           1       0
# 16           1       1
# 17           1       1
# 18           1       1
# 19           1       1

# %%
# Calculate the confusion matrix.
cm = confusion_matrix(y_test, y_pred)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0            0            8
# Actual 1            0          148

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.00      0.00      1.00      0.00      0.00      0.00         8
#           1       0.95      1.00      0.00      0.97      0.00      0.00       148
#
# avg / total       0.90      0.95      0.05      0.92      0.00      0.00       156
# C:\Users\Michelle\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Calculate the Random Forest Classifer model accuracy score.
acc_score = accuracy_score(y_test, y_pred)

# %%
# Display the results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report_imbalanced(y_test, y_pred))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0            0            8
# Actual 1            0          148
# Accuracy Score : 0.9487179487179487
# Classification Report
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.00      0.00      1.00      0.00      0.00      0.00         8
#           1       0.95      1.00      0.00      0.97      0.00      0.00       148
#
# avg / total       0.90      0.95      0.05      0.92      0.00      0.00       156
# C:\Users\Michelle\anaconda3\envs\mlenv\lib\site-packages\sklearn\metrics\_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
